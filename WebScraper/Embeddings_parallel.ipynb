# %%
# Cell 2 — Imports & Config
import os, time, pickle, random
import pandas as pd
import numpy as np
import torch
from torch_geometric.data import Data
from neo4j import GraphDatabase
from neo4j.exceptions import ServiceUnavailable, TransientError
from concurrent.futures import ThreadPoolExecutor, as_completed


# Neo4j connection
NEO4J_URI = "bolt://localhost:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "12345678"
DATABASE = "neo4jads"


# Radii per category (meters)
RADII = {"CERCA_DE_CAT1": 600.0, "CERCA_DE_CAT2": 1200.0, "CERCA_DE_CAT3": 2400.0}


# Classes (11)
CLASSES = [
'sport_and_leisure','medical','education_prim','veterinary','food_and_drink_stores',
'arts_and_entertainment','food_and_drink','park_like','security','religion','education_sup'
]

# %%
# Cell 3 — Cypher queries
NODE_QUERY = """
MATCH (d:Departamento {id:$apt_id})
RETURN elementId(d) AS id, 'Departamento' AS label,
d.id AS apt_id, d.latitude AS lat, d.longitude AS lon, null AS cat
UNION
MATCH (d:Departamento {id:$apt_id})-[:CERCA_DE_CAT1|CERCA_DE_CAT2|CERCA_DE_CAT3]->(p:POI)
WHERE p.class = $class
RETURN elementId(p) AS id, 'POI' AS label,
null AS apt_id, null AS lat, null AS lon, p.cat AS cat
"""


REL_QUERY = """
MATCH (d:Departamento {id:$apt_id})-[r:CERCA_DE_CAT1|CERCA_DE_CAT2|CERCA_DE_CAT3]->(p:POI)
WHERE p.class = $class
WITH elementId(d) AS source, elementId(p) AS target, type(r) AS t, r.distancia_metros AS dist
WITH source, target,
CASE t
WHEN 'CERCA_DE_CAT1' THEN CASE WHEN 1.0 - dist / $r_cat1 > 0.001 THEN 1.0 - dist / $r_cat1 ELSE 0.001 END
WHEN 'CERCA_DE_CAT2' THEN CASE WHEN 1.0 - dist / $r_cat2 > 0.001 THEN 1.0 - dist / $r_cat2 ELSE 0.001 END
ELSE CASE WHEN 1.0 - dist / $r_cat3 > 0.001 THEN 1.0 - dist / $r_cat3 ELSE 0.001 END
END AS weight
RETURN source, target, weight
"""

# %%
# Cell 4 — Export function (session-aware)
def export_apartment_class_graph(apt_id: int, class_name: str, session=None) -> Data | None:
    """Return PyG Data for (apt × class), or None if no nodes/edges.
    In threaded mode we pass a session; for ad-hoc tests session can be None.
    """
    # If no session provided, open a temporary one (kept for developer convenience)
    if session is None:
        driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
        try:
            with driver.session(database=DATABASE) as s:
                return export_apartment_class_graph(apt_id, class_name, session=s)
        finally:
            driver.close()


    nodes = session.run(NODE_QUERY, {"apt_id": apt_id, "class": class_name}).data()
    if not nodes:
        return None
    node_df = pd.DataFrame(nodes)
    id_map = {nid: i for i, nid in enumerate(node_df["id"].tolist())}


    edges = session.run(
        REL_QUERY,
        {
            "apt_id": apt_id, "class": class_name,
            "r_cat1": RADII["CERCA_DE_CAT1"],
            "r_cat2": RADII["CERCA_DE_CAT2"],
            "r_cat3": RADII["CERCA_DE_CAT3"],
        },
    ).data()
    if not edges:
        print(f"No edges found for apartment {apt_id}, class {class_name}")
        return None
    edge_df = pd.DataFrame(edges)


    edge_index = torch.tensor([
        [id_map[s] for s in edge_df["source"]],
        [id_map[t] for t in edge_df["target"]],
    ], dtype=torch.long)
    edge_attr = torch.tensor(edge_df["weight"].values, dtype=torch.float).unsqueeze(1)


    feats: list[list[float]] = []
    for _, row in node_df.iterrows():
        if row["label"] == "Departamento":
            feats.append([1.0, 0.0, 0.0, 0.0])
        else:
            onehot = [0.0, 0.0, 0.0, 0.0]
            cat_val = row.get("cat")
            if cat_val is not None:
                try:
                    idx = int(cat_val)
                    if 0 <= idx < 4:
                        onehot[idx] = 1.0
                except (ValueError, TypeError):
                    pass
            feats.append(onehot)


    x = torch.tensor(np.array(feats), dtype=torch.float)
    return Data(x=x, edge_index=edge_index, edge_attr=edge_attr, apt_id=apt_id, poi_class=class_name)

# %%
# Batch/parallel config
OUTPUT_FILE = "apartment_graphs_bottom.pkl" # this machine's file
BATCH_SIZE = 1000 # change freely
MAX_WORKERS = 8 # adjust to CPU/DB capacity
MAX_RETRIES = 2 # apartment-level retries
RETRY_DELAY = 5

# %%
# Cell 5 — Load dataset & prepare pending IDs (bottom-up)
df_deptos = pd.read_csv('Datasets/dataset_final.csv')

if os.path.exists(OUTPUT_FILE):
    with open(OUTPUT_FILE, 'rb') as f:
        all_graphs: dict[int, dict[str, Data | None]] = pickle.load(f)
    done_ids = set(all_graphs.keys())
    print(f"Resuming: {len(done_ids)} apartments already done (bottom-up file).")
else:
    all_graphs = {}
    done_ids = set()


apt_ids = df_deptos['id'].tolist()[::-1] # bottom-up
pending_ids = [i for i in apt_ids if i not in done_ids]
batch_ids = pending_ids[:BATCH_SIZE]
print(f"Processing {len(batch_ids)} apartments in this batch (remaining after this: {len(pending_ids)-len(batch_ids)})")
# Out:
# Resuming: 4950 apartments already done (bottom-up file).
# Processing 5000 apartments in this batch (remaining after this: 15265)

# %%
def process_apartment_once(apt_id: int) -> tuple[int, dict[str, Data | None] | None, str | None]:
    """One attempt. Returns (apt_id, graphs_dict, error_str)."""
    try:
        driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
        try:
            with driver.session(database=DATABASE) as session:
                graphs: dict[str, Data | None] = {}
                for cls in CLASSES:
                    g = export_apartment_class_graph(apt_id, cls, session=session)
                    graphs[cls] = g # may be None if no POIs
                return apt_id, graphs, None
        finally:
            driver.close()
    except (ServiceUnavailable, TransientError, Exception) as e:
        return apt_id, None, str(e)


def process_apartment_with_retries(apt_id: int) -> tuple[int, dict[str, Data | None] | None, str | None]:
    for attempt in range(1, MAX_RETRIES + 2):
        aid, graphs, err = process_apartment_once(apt_id)
        if err is None:
            return aid, graphs, None
        if attempt <= MAX_RETRIES:
            time.sleep(RETRY_DELAY)
    return aid, None, err # final failure

# %%
start_batch = time.time()


results: list[tuple[int, dict[str, Data | None] | None, str | None]] = []
with ThreadPoolExecutor(max_workers=MAX_WORKERS) as ex:
    futs = {ex.submit(process_apartment_with_retries, aid): aid for aid in batch_ids}
    for i, fut in enumerate(as_completed(futs), 1):
        aid = futs[fut]
        try:
            apt_id, graphs, err = fut.result()
        except Exception as e:
            apt_id, graphs, err = aid, None, f"worker crash: {e}"
        ok = (err is None and graphs is not None)
        status = "OK" if ok else f"ERR: {err}"
        print(f"[{i}/{len(batch_ids)}] apt={apt_id} -> {status}")
        if ok:
            all_graphs[apt_id] = graphs
            with open(OUTPUT_FILE, 'wb') as f:
                pickle.dump(all_graphs, f)


print(f"✅ Batch finished in {time.time()-start_batch:.2f}s. Total saved so far: {len(all_graphs)}")
# Out:
# [1/5000] apt=2859780596 -> OK
# [2/5000] apt=2844409034 -> OK
# [3/5000] apt=2848023442 -> OK
# [4/5000] apt=1569588671 -> OK
# [5/5000] apt=1537274739 -> OK
# [6/5000] apt=2849630118 -> OK
# [7/5000] apt=2861588902 -> OK
# [8/5000] apt=2863530320 -> OK
# [9/5000] apt=2859410746 -> OK
# [10/5000] apt=2836626950 -> OK
# [11/5000] apt=2849514214 -> OK
# [12/5000] apt=2854169188 -> OK
# [13/5000] apt=1584098509 -> OK
# [14/5000] apt=1589143899 -> OK
# [15/5000] apt=2843365020 -> OK
# [16/5000] apt=1589193779 -> OK
# [17/5000] apt=2858092214 -> OK
# [18/5000] apt=2855701542 -> OK
# No edges found for apartment 1589105543, class religion
# No edges found for apartment 2842128396, class religion
# [19/5000] apt=2843439822 -> OK
# No edges found for apartment 2742373722, class veterinary
# No edges found for apartment 2742373722, class food_and_drink_stores
# No edges found for apartment 2815058264, class religion
# No edges found for apartment 2742373722, class food_and_drink
# No edges found for apartment 1586650997, class veterinary
# No edges found for apartment 1586650997, class security
# No edges found for apartment 2843497488, class education_prim
# No edges found for apartment 2843497488, class food_and_drink_stores
# [20/5000] apt=1568000491 -> OK
# No edges found for apartment 2857822156, class park_like
# No edges found for apartment 2843497488, class food_and_drink
# No edges found for apartment 2857822156, class religion
# No edges found for apartment 2843497488, class security
# No edges found for apartment 2843497488, class religion
# No edges found for apartment 2709916292, class education_prim
# No edges found for apartment 2862632650, class education_prim
# No edges found for apartment 2862632650, class veterinary
# No edges found for apartment 1578548455, class religion
# No edges found for apartment 2862632650, class security
# No edges found for apartment 2709916292, class security
# No edges found for apartment 2862632650, class religion
# [21/5000] apt=1591362149 -> OK
# No edges found for apartment 1554374023, class veterinary
# No edges found for apartment 1554374023, class security
# No edges found for apartment 2850440344, class education_prim
# [22/5000] apt=2816928104 -> OK
# No edges found for apartment 2850440344, class security
# No edges found for apartment 1591777267, class food_and_drink_stores
# No edges found for apartment 1591777267, class food_and_drink
# No edges found for apartment 1591777267, class security
# No edges found for apartment 1591777267, class religion
# [23/5000] apt=1588402385 -> OK
# No edges found for apartment 1589025789, class religion
# No edges found for apartment 1584415371, class park_like
# No edges found for apartment 1584415371, class religion
# [24/5000] apt=1586649275 -> OK
# No edges found for apartment 2766907450, class food_and_drink
# No edges found for apartment 2841968156, class education_prim
# No edges found for apartment 2781991824, class park_like
# No edges found for apartment 2841968156, class security
# No edges found for apartment 2781991824, class religion
# No edges found for apartment 2861549604, class education_prim
# No edges found for apartment 2861549604, class food_and_drink_stores
# No edges found for apartment 2861549604, class food_and_drink
# No edges found for apartment 2853736140, class security
# No edges found for apartment 2853736140, class religion
# No edges found for apartment 2861549604, class security
# No edges found for apartment 2861549604, class religion
# No edges found for apartment 1578346761, class education_prim
# No edges found for apartment 1578346761, class food_and_drink_stores
# [25/5000] apt=1589625415 -> OK
# No edges found for apartment 2771059532, class food_and_drink_stores
# No edges found for apartment 1578346761, class food_and_drink
# No edges found for apartment 1578346761, class security
# No edges found for apartment 1578346761, class religion
# No edges found for apartment 2771059522, class security
# No edges found for apartment 2771059522, class religion
# No edges found for apartment 2771059532, class food_and_drink
# No edges found for apartment 2771059532, class security
# No edges found for apartment 2771059532, class religion
# No edges found for apartment 2858306960, class education_prim
# No edges found for apartment 2858306960, class veterinary
# No edges found for apartment 1584732577, class religion
# No edges found for apartment 2858306960, class food_and_drink_stores
# No edges found for apartment 2858306960, class food_and_drink
# No edges found for apartment 2858306960, class security
# No edges found for apartment 2858306960, class religion
# No edges found for apartment 1557575627, class food_and_drink
# No edges found for apartment 1557575627, class park_like
# No edges found for apartment 2803897328, class religion
# No edges found for apartment 1567172175, class education_prim
# No edges found for apartment 1567172175, class veterinary
# No edges found for apartment 1572120619, class food_and_drink
# No edges found for apartment 1567172175, class security
# No edges found for apartment 1567172175, class religion
# [26/5000] apt=1585515205 -> OK
# No edges found for apartment 2860444942, class veterinary
# No edges found for apartment 2834069472, class religion
# No edges found for apartment 2860444942, class food_and_drink_stores
# No edges found for apartment 2767234184, class park_like
# No edges found for apartment 2767234184, class religion
# No edges found for apartment 2860444942, class food_and_drink
# No edges found for apartment 2860444942, class park_like
# No edges found for apartment 1572139015, class veterinary
# No edges found for apartment 1572139015, class security
# No edges found for apartment 1589363023, class religion
# No edges found for apartment 2790976056, class veterinary
# No edges found for apartment 2863621046, class food_and_drink_stores
# [27/5000] apt=2858108204 -> OK
# No edges found for apartment 2863621046, class food_and_drink
# No edges found for apartment 2790976056, class security
# No edges found for apartment 2863621046, class security
# No edges found for apartment 2863621046, class religion
# No edges found for apartment 1533486457, class park_like
# No edges found for apartment 1533486457, class religion
# No edges found for apartment 1578281139, class park_like
# No edges found for apartment 1578281139, class religion
# No edges found for apartment 1586009949, class education_prim
# No edges found for apartment 1558583695, class education_prim
# No edges found for apartment 1558583695, class veterinary
# [28/5000] apt=2860971904 -> OK
# No edges found for apartment 1586009949, class food_and_drink
# No edges found for apartment 1586009949, class park_like
# No edges found for apartment 1558583695, class security
# No edges found for apartment 1558583695, class religion
# No edges found for apartment 1543370415, class education_prim
# No edges found for apartment 1543370415, class veterinary
# No edges found for apartment 2851876832, class education_prim
# No edges found for apartment 2851876832, class food_and_drink_stores
# No edges found for apartment 1543370415, class security
# No edges found for apartment 2851876832, class food_and_drink
# No edges found for apartment 2851876832, class security
# No edges found for apartment 2851876832, class religion
# No edges found for apartment 1537093155, class education_prim
# No edges found for apartment 1537093155, class food_and_drink_stores
# [29/5000] apt=2812298922 -> OK
# No edges found for apartment 1537093155, class food_and_drink
# No edges found for apartment 1537093155, class security
# No edges found for apartment 1537093155, class religion
# No edges found for apartment 2734240300, class religion
# No edges found for apartment 2824121672, class education_prim
# No edges found for apartment 2824121672, class food_and_drink_stores
# No edges found for apartment 2824121672, class food_and_drink
# No edges found for apartment 2824121672, class security
# No edges found for apartment 2824121672, class religion
# No edges found for apartment 2853412888, class religion
# No edges found for apartment 2863687032, class security
# No edges found for apartment 2863687032, class religion
# No edges found for apartment 2798832316, class education_prim
# No edges found for apartment 2798832316, class veterinary
# No edges found for apartment 2836872892, class security
# No edges found for apartment 1588605329, class veterinary
# No edges found for apartment 2836872892, class religion
# No edges found for apartment 2798832316, class security
# No edges found for apartment 1582674655, class education_prim
# No edges found for apartment 2798832316, class religion
# No edges found for apartment 1588605329, class security
# No edges found for apartment 1449152537, class education_prim
# No edges found for apartment 1449152537, class food_and_drink_stores
# [30/5000] apt=2844061342 -> OK
# No edges found for apartment 1582674655, class security
# No edges found for apartment 1449152537, class food_and_drink
# No edges found for apartment 1449152537, class security
# No edges found for apartment 1449152537, class religion
# No edges found for apartment 1584718985, class food_and_drink_stores
# No edges found for apartment 1584718985, class food_and_drink
# No edges found for apartment 1584718985, class security
# No edges found for apartment 1584718985, class religion
# [31/5000] apt=1584615617 -> OK
# No edges found for apartment 2742281602, class security
# No edges found for apartment 2742281602, class religion
# [32/5000] apt=1591818209 -> OK
# No edges found for apartment 1568145043, class veterinary
# No edges found for apartment 2861112706, class religion
# [33/5000] apt=2840561384 -> OK
# No edges found for apartment 1585227425, class security
# No edges found for apartment 1585227425, class religion
# [34/5000] apt=1590359197 -> OK
# No edges found for apartment 2863746856, class security
# No edges found for apartment 2863746856, class religion
# No edges found for apartment 2799361930, class security
# No edges found for apartment 2799361930, class religion
# No edges found for apartment 1589908987, class veterinary
# No edges found for apartment 2799322694, class security
# No edges found for apartment 2799322694, class religion
# No edges found for apartment 2761751144, class religion
# No edges found for apartment 2730175114, class religion
# [35/5000] apt=1591866761 -> OK
# No edges found for apartment 1565469635, class religion
# No edges found for apartment 2830713142, class religion
# No edges found for apartment 2830713144, class religion
# [36/5000] apt=1574810813 -> OK
# No edges found for apartment 2775224708, class food_and_drink_stores
# No edges found for apartment 2775224708, class food_and_drink
# No edges found for apartment 1534808821, class food_and_drink_stores
# No edges found for apartment 2775224708, class security
# No edges found for apartment 2775224708, class religion
# No edges found for apartment 1592710311, class food_and_drink
# No edges found for apartment 1572632881, class food_and_drink_stores
# No edges found for apartment 2858027954, class food_and_drink_stores
# No edges found for apartment 1592710311, class security
# [37/5000] apt=2821884234 -> OK
# No edges found for apartment 1534808821, class food_and_drink
# No edges found for apartment 2863756966, class food_and_drink_stores
# No edges found for apartment 2840834860, class food_and_drink_stores
# No edges found for apartment 1572632881, class food_and_drink
# No edges found for apartment 1534808821, class religion
# No edges found for apartment 2858027954, class food_and_drink
# No edges found for apartment 1572632881, class religion
# No edges found for apartment 1569814441, class food_and_drink_stores
# No edges found for apartment 2858027954, class religion
# No edges found for apartment 1591677207, class food_and_drink
# No edges found for apartment 2863756966, class food_and_drink
# No edges found for apartment 2840834860, class food_and_drink
# No edges found for apartment 2840834860, class security
# No edges found for apartment 2863756966, class religion
# No edges found for apartment 2840834860, class religion
# No edges found for apartment 1569814441, class food_and_drink
# No edges found for apartment 1569814441, class religion
# No edges found for apartment 1549920653, class food_and_drink
# No edges found for apartment 1549920653, class religion
# No edges found for apartment 2747484526, class religion
# No edges found for apartment 1550655961, class religion
# No edges found for apartment 2750216670, class religion
# No edges found for apartment 1591796825, class religion
# No edges found for apartment 1550904337, class religion
# No edges found for apartment 1564596225, class religion
# No edges found for apartment 1583861295, class religion
# No edges found for apartment 2853410394, class religion
# No edges found for apartment 2853863388, class religion
# No edges found for apartment 1537736173, class religion
# [38/5000] apt=2782729986 -> OK
# No edges found for apartment 1587141415, class religion
# No edges found for apartment 1585153785, class religion
# No edges found for apartment 2861119972, class religion
# No edges found for apartment 1575719893, class religion
# [39/5000] apt=2853372638 -> OK
# No edges found for apartment 1536347851, class religion
# No edges found for apartment 2859629458, class religion
# No edges found for apartment 2864334308, class religion
# [40/5000] apt=1586155953 -> OK
# No edges found for apartment 2860971900, class religion
# [41/5000] apt=1591575567 -> OK
# No edges found for apartment 2830349648, class religion
# No edges found for apartment 1562371521, class religion
# No edges found for apartment 1577646535, class religion
# [42/5000] apt=1573340571 -> OK
# No edges found for apartment 2839305876, class religion
# No edges found for apartment 1589126947, class religion
# [43/5000] apt=1591757259 -> OK
# No edges found for apartment 1572289369, class religion
# [44/5000] apt=2847841886 -> OK
# No edges found for apartment 2861158830, class religion
# No edges found for apartment 1583324733, class religion
# No edges found for apartment 2806752604, class religion
# [45/5000] apt=1572764707 -> OK
# No edges found for apartment 2857791844, class food_and_drink
# No edges found for apartment 2837022088, class food_and_drink
# [46/5000] apt=2784045522 -> OK
# No edges found for apartment 1588143195, class food_and_drink
# No edges found for apartment 2860869192, class food_and_drink
# No edges found for apartment 1586789997, class food_and_drink
# [47/5000] apt=1584764497 -> OK
# No edges found for apartment 2817594198, class food_and_drink
# [48/5000] apt=2864046334 -> OK
# No edges found for apartment 1585162985, class food_and_drink
# No edges found for apartment 1542812083, class food_and_drink
# [49/5000] apt=2765703046 -> OK
# [50/5000] apt=1582827341 -> OK
# [51/5000] apt=2864292858 -> OK
# [52/5000] apt=1513454981 -> OK
# [53/5000] apt=2851522594 -> OK
# [54/5000] apt=2835106792 -> OK
# [55/5000] apt=2842461310 -> OK
# [56/5000] apt=2848794804 -> OK
# [57/5000] apt=2860548804 -> OK
# [58/5000] apt=2863820322 -> OK
# [59/5000] apt=2860522736 -> OK
# [60/5000] apt=1583417169 -> OK
# [61/5000] apt=1571723887 -> OK
# [62/5000] apt=1536510609 -> OK
# [63/5000] apt=1536105451 -> OK
# [64/5000] apt=2790980506 -> OK
# [65/5000] apt=2860773548 -> OK
# [66/5000] apt=2786340086 -> OK
# [67/5000] apt=1583888235 -> OK
# [68/5000] apt=1572258539 -> OK
# [69/5000] apt=1591412557 -> OK
# [70/5000] apt=1591606945 -> OK
# [71/5000] apt=2837841398 -> OK
# [72/5000] apt=2860706880 -> OK
# [73/5000] apt=2864470600 -> OK
# [74/5000] apt=2834726352 -> OK
# [75/5000] apt=1566525987 -> OK
# [76/5000] apt=1538443621 -> OK
# [77/5000] apt=1528966511 -> OK
# [78/5000] apt=1547264501 -> OK
# [79/5000] apt=1591096161 -> OK
# [80/5000] apt=1571287215 -> OK
# [81/5000] apt=2780911040 -> OK
# [82/5000] apt=1571494633 -> OK
# [83/5000] apt=2830343740 -> OK
# [84/5000] apt=1574088963 -> OK
# No edges found for apartment 1545986631, class veterinary
# No edges found for apartment 1571754635, class religion
# No edges found for apartment 1571754635, class education_sup
# No edges found for apartment 1552221769, class veterinary
# No edges found for apartment 1539986141, class food_and_drink
# No edges found for apartment 1539986141, class religion
# No edges found for apartment 2856084902, class veterinary
# No edges found for apartment 1539986141, class education_sup
# No edges found for apartment 2853022118, class veterinary
# No edges found for apartment 2856084902, class arts_and_entertainment
# No edges found for apartment 2856084902, class religion
# No edges found for apartment 2824908690, class veterinary
# [85/5000] apt=1545006039 -> OK
# No edges found for apartment 2824908690, class religion
# No edges found for apartment 2824908690, class education_sup
# No edges found for apartment 2859070818, class religion
# [86/5000] apt=2854986352 -> OK
# No edges found for apartment 2832015882, class religion
# No edges found for apartment 2773114870, class veterinary
# No edges found for apartment 1591849163, class veterinary
# No edges found for apartment 2824821260, class religion
# No edges found for apartment 1588251911, class veterinary
# [87/5000] apt=1549956427 -> OK
# No edges found for apartment 1580113045, class religion
# No edges found for apartment 1564139741, class religion
# No edges found for apartment 1580501209, class veterinary
# No edges found for apartment 1580501209, class arts_and_entertainment
# No edges found for apartment 1580501209, class food_and_drink
# No edges found for apartment 1580501209, class religion
# No edges found for apartment 1580501209, class education_sup
# No edges found for apartment 1557832673, class veterinary
# [88/5000] apt=2857144966 -> OK
# No edges found for apartment 2823423606, class veterinary
# No edges found for apartment 1580203179, class veterinary
# No edges found for apartment 1540074119, class veterinary
# No edges found for apartment 1580203179, class food_and_drink
# No edges found for apartment 2823423606, class religion
# No edges found for apartment 2834010376, class veterinary
# No edges found for apartment 2823423606, class education_sup
# No edges found for apartment 1540074119, class religion
# No edges found for apartment 1580203179, class education_sup
# No edges found for apartment 1540074119, class education_sup
# No edges found for apartment 2834010376, class education_sup
# No edges found for apartment 1589851283, class religion
# [89/5000] apt=2741900366 -> OK
# No edges found for apartment 2755224816, class religion
# No edges found for apartment 2755173016, class religion
# No edges found for apartment 1589776577, class veterinary
# No edges found for apartment 1552807197, class arts_and_entertainment
# No edges found for apartment 1589776577, class religion
# No edges found for apartment 2839401476, class veterinary
# No edges found for apartment 1588297961, class veterinary
# No edges found for apartment 2859162992, class religion
# No edges found for apartment 2863718148, class veterinary
# No edges found for apartment 2839401476, class religion
# No edges found for apartment 2861742778, class veterinary
# No edges found for apartment 2863544410, class arts_and_entertainment
# No edges found for apartment 2861742778, class food_and_drink_stores
# No edges found for apartment 2861587416, class veterinary
# [90/5000] apt=2848977278 -> OK
# No edges found for apartment 1588297961, class education_sup
# No edges found for apartment 2863718148, class religion
# No edges found for apartment 2861139964, class veterinary
# No edges found for apartment 2861742778, class food_and_drink
# No edges found for apartment 2863544410, class education_sup
# No edges found for apartment 2861742778, class religion
# No edges found for apartment 2859148856, class veterinary
# No edges found for apartment 2861587416, class education_sup
# No edges found for apartment 2861139964, class religion
# No edges found for apartment 1539400901, class sport_and_leisure
# No edges found for apartment 2858136254, class food_and_drink
# No edges found for apartment 2831447796, class veterinary
# No edges found for apartment 1580110297, class veterinary
# No edges found for apartment 2858136254, class education_sup
# No edges found for apartment 2831447796, class education_sup
# No edges found for apartment 2739521960, class veterinary
# No edges found for apartment 1539971889, class veterinary
# No edges found for apartment 2839913492, class park_like
# No edges found for apartment 1580110297, class education_sup
# [91/5000] apt=1568435169 -> OK
# No edges found for apartment 1539971889, class religion
# No edges found for apartment 1583770781, class education_prim
# No edges found for apartment 1533486445, class education_prim
# No edges found for apartment 1583770781, class veterinary
# No edges found for apartment 1578293863, class education_primNo edges found for apartment 1583770781, class food_and_drink_stores
#
# No edges found for apartment 2739521960, class education_sup
# No edges found for apartment 1589167561, class veterinary
# No edges found for apartment 1578293863, class religion
# No edges found for apartment 1589167561, class food_and_drink
# No edges found for apartment 1589167561, class religion
# No edges found for apartment 1556280387, class religion
# No edges found for apartment 2775211144, class veterinary
# No edges found for apartment 2851941306, class security
# No edges found for apartment 1590712649, class education_prim
# No edges found for apartment 1590712649, class veterinary
# No edges found for apartment 1584669351, class education_primNo edges found for apartment 2775211144, class religion
#
# No edges found for apartment 2861140238, class security
# No edges found for apartment 1584669351, class veterinary
# No edges found for apartment 1584669351, class food_and_drink_stores
# No edges found for apartment 1590712649, class park_like
# No edges found for apartment 2769396860, class security
# No edges found for apartment 2769396860, class religion
# No edges found for apartment 1590712649, class religion
# [92/5000] apt=1542208779 -> OK
# No edges found for apartment 2852489462, class veterinary
# No edges found for apartment 1583750733, class security
# No edges found for apartment 2852946184, class religion
# No edges found for apartment 1568170921, class education_prim
# No edges found for apartment 2852489462, class religion
# No edges found for apartment 1568170921, class religion
# No edges found for apartment 1532542791, class veterinary
# No edges found for apartment 1588357105, class education_prim
# No edges found for apartment 1588357105, class food_and_drink_stores
# No edges found for apartment 1561322385, class veterinary
# No edges found for apartment 2752642386, class veterinary
# No edges found for apartment 1532542791, class religion
# [93/5000] apt=2851411254 -> OK
# No edges found for apartment 2750903850, class veterinary
# No edges found for apartment 2752642386, class food_and_drink
# No edges found for apartment 2728466924, class veterinary
# No edges found for apartment 2752642386, class religion
# No edges found for apartment 1561322385, class religion
# No edges found for apartment 1585984747, class education_prim
# No edges found for apartment 1585984747, class veterinary
# No edges found for apartment 1585984747, class food_and_drink_stores
# No edges found for apartment 2750903850, class religion
# No edges found for apartment 1582647329, class education_prim
# No edges found for apartment 1577216429, class veterinary
# No edges found for apartment 1582647329, class food_and_drink_stores
# No edges found for apartment 1533936505, class veterinary
# No edges found for apartment 1584014121, class religion
# No edges found for apartment 1531468601, class veterinary
# No edges found for apartment 1529916799, class education_prim
# No edges found for apartment 1529916799, class veterinary
# No edges found for apartment 1529916799, class food_and_drink_stores
# No edges found for apartment 2857702712, class veterinary
# No edges found for apartment 1568048053, class religion
# No edges found for apartment 1531468601, class religion
# No edges found for apartment 2854573678, class veterinary
# No edges found for apartment 1549411781, class veterinary
# No edges found for apartment 2857702712, class religion
# No edges found for apartment 1589506601, class education_prim
# No edges found for apartment 1589506601, class veterinary
# [94/5000] apt=2854499344 -> OK
# No edges found for apartment 2854560736, class education_prim
# No edges found for apartment 1549411781, class food_and_drink
# No edges found for apartment 1589506601, class food_and_drink
# No edges found for apartment 2822183242, class veterinary
# No edges found for apartment 1549411781, class religion
# No edges found for apartment 1589506601, class security
# No edges found for apartment 2854560736, class food_and_drink_stores
# No edges found for apartment 1578293861, class education_prim
# No edges found for apartment 1555266755, class veterinary
# No edges found for apartment 2822183242, class food_and_drink
# No edges found for apartment 1578293861, class food_and_drink_stores
# No edges found for apartment 2859092684, class veterinary
# No edges found for apartment 2822183242, class religion
# No edges found for apartment 2859092684, class food_and_drink_stores
# No edges found for apartment 1547043457, class education_prim
# No edges found for apartment 1555266755, class food_and_drink
# No edges found for apartment 2695897284, class education_prim
# No edges found for apartment 1555266755, class religion
# No edges found for apartment 2859092684, class religion
# No edges found for apartment 2695897284, class religion
# No edges found for apartment 2756233142, class veterinary
# No edges found for apartment 1585099225, class veterinary
# No edges found for apartment 2756233142, class food_and_drink
# No edges found for apartment 1585099225, class food_and_drink_stores
# No edges found for apartment 2756233142, class religion
# No edges found for apartment 1585099225, class food_and_drink
# [95/5000] apt=2848713776 -> OK
# No edges found for apartment 1585099225, class religion
# No edges found for apartment 1547710527, class veterinary
# No edges found for apartment 1547710527, class religion
# No edges found for apartment 2854586442, class education_prim
# No edges found for apartment 2854586442, class veterinary
# No edges found for apartment 2854586442, class food_and_drink
# No edges found for apartment 1568075447, class veterinary
# No edges found for apartment 2854586442, class park_like
# No edges found for apartment 2854586442, class security
# No edges found for apartment 2854586442, class religion
# No edges found for apartment 2856775328, class security
# No edges found for apartment 2856775328, class religion
# No edges found for apartment 1588475967, class education_prim
# No edges found for apartment 1568075447, class religion
# No edges found for apartment 1574537301, class education_prim
# No edges found for apartment 1574537301, class veterinary
# No edges found for apartment 1588475967, class religion
# No edges found for apartment 1584614443, class security
# No edges found for apartment 1574537301, class park_like
# No edges found for apartment 1574537301, class religion
# [96/5000] apt=2850861296 -> OK
# No edges found for apartment 1585859391, class veterinary
# No edges found for apartment 2795297460, class security
# No edges found for apartment 1568226059, class veterinary
# No edges found for apartment 2856016792, class security
# No edges found for apartment 1585859391, class food_and_drink
# No edges found for apartment 1489153235, class veterinary
# No edges found for apartment 1591217767, class food_and_drink
# No edges found for apartment 1585859391, class religion
# No edges found for apartment 1489153235, class food_and_drink_stores
# No edges found for apartment 1568226059, class food_and_drink
# No edges found for apartment 1569014527, class park_like
# No edges found for apartment 1568226059, class religion
# No edges found for apartment 1569014527, class religion
# No edges found for apartment 1489153235, class food_and_drink
# No edges found for apartment 1489153235, class religion
# No edges found for apartment 1570791225, class education_prim
# No edges found for apartment 1570791225, class veterinary
# No edges found for apartment 1575603475, class education_prim
# No edges found for apartment 1570791225, class food_and_drink_stores
# No edges found for apartment 1575603475, class veterinary
# No edges found for apartment 1575603475, class food_and_drink_stores
# No edges found for apartment 1575603475, class food_and_drink
# [97/5000] apt=2802232248 -> OK
# No edges found for apartment 1575603475, class park_like
# No edges found for apartment 1575603475, class religion
# No edges found for apartment 1575603475, class education_sup
# No edges found for apartment 2858255540, class security
# No edges found for apartment 2855017580, class security
# No edges found for apartment 2753461766, class security
# No edges found for apartment 2812904860, class veterinary
# No edges found for apartment 1575602637, class security
# No edges found for apartment 2812904860, class food_and_drink
# No edges found for apartment 1589054701, class veterinary
# No edges found for apartment 2849543644, class security
# No edges found for apartment 2812904860, class religion
# No edges found for apartment 1571669349, class security
# No edges found for apartment 2753441608, class security
# No edges found for apartment 1589054701, class food_and_drink
# No edges found for apartment 1589054701, class religion
# No edges found for apartment 2680693942, class veterinary
# No edges found for apartment 2744851056, class veterinary
# No edges found for apartment 2863871778, class education_prim
# No edges found for apartment 2840443858, class veterinary
# No edges found for apartment 1585318083, class security
# No edges found for apartment 1591439193, class food_and_drink
# [98/5000] apt=2840497850 -> OK
# No edges found for apartment 2744851056, class religion
# No edges found for apartment 1585318083, class religion
# No edges found for apartment 2680693942, class religion
# No edges found for apartment 2840443858, class food_and_drink_stores
# No edges found for apartment 2856037046, class food_and_drink_stores
# No edges found for apartment 1591439193, class religion
# No edges found for apartment 2831533394, class education_prim
# No edges found for apartment 2824172844, class veterinary
# No edges found for apartment 2840443858, class food_and_drink
# No edges found for apartment 2793077704, class education_prim
# No edges found for apartment 1539592793, class security
# No edges found for apartment 2863871778, class religion
# No edges found for apartment 2856037046, class food_and_drink
# No edges found for apartment 1539592793, class religion
# No edges found for apartment 2840443858, class religion
# No edges found for apartment 2793077704, class food_and_drink_stores
# No edges found for apartment 2856037046, class religion
# No edges found for apartment 2831533394, class food_and_drink
# No edges found for apartment 2824172844, class religion
# No edges found for apartment 2793077704, class food_and_drink
# No edges found for apartment 2765806590, class veterinary
# No edges found for apartment 2793077704, class security
# No edges found for apartment 2793077704, class religion
# No edges found for apartment 2633465212, class education_prim
# No edges found for apartment 2765806590, class food_and_drink_stores
# No edges found for apartment 2633465212, class veterinary
# No edges found for apartment 1586351235, class education_prim
# No edges found for apartment 1592825975, class veterinary
# No edges found for apartment 1585325691, class education_prim
# No edges found for apartment 1585325691, class veterinary
# No edges found for apartment 2633465212, class park_like
# No edges found for apartment 2765806590, class religion
# No edges found for apartment 1578374993, class veterinary
# No edges found for apartment 1586351235, class food_and_drinkNo edges found for apartment 2633465212, class religion
#
# No edges found for apartment 1586351235, class park_like
# No edges found for apartment 1585325691, class park_like
# No edges found for apartment 1592825975, class religion
# No edges found for apartment 1549747369, class education_prim
# No edges found for apartment 1585325691, class religion
# No edges found for apartment 1578374993, class religion
# No edges found for apartment 2855505708, class veterinary
# No edges found for apartment 1549747369, class religion
# No edges found for apartment 2832042476, class park_like
# No edges found for apartment 2864224252, class veterinary
# No edges found for apartment 2832042476, class religion
# No edges found for apartment 2855505708, class food_and_drink_stores
# No edges found for apartment 1558977759, class security
# [99/5000] apt=1586186891 -> OK
# No edges found for apartment 1558977759, class religion
# No edges found for apartment 2832690382, class education_prim
# No edges found for apartment 2855505708, class food_and_drink
# No edges found for apartment 1589496157, class education_prim
# No edges found for apartment 2852902932, class security
# No edges found for apartment 2864224252, class park_like
# No edges found for apartment 2855505708, class religion
# No edges found for apartment 2864224252, class religion
# No edges found for apartment 2837300508, class religion
# No edges found for apartment 2832690382, class park_like
# No edges found for apartment 1552312839, class veterinary
# No edges found for apartment 2832690382, class religion
# No edges found for apartment 1552312839, class food_and_drink_stores
# No edges found for apartment 2743387630, class religion
# No edges found for apartment 1589496157, class religion
# No edges found for apartment 2854625204, class veterinary
# No edges found for apartment 1552312839, class food_and_drink
# No edges found for apartment 2840855632, class veterinary
# No edges found for apartment 2846905174, class food_and_drink_stores
# No edges found for apartment 1552312839, class religion
# No edges found for apartment 2840855632, class food_and_drink_stores
# No edges found for apartment 2846905174, class food_and_drink
# No edges found for apartment 2840855632, class food_and_drink
# No edges found for apartment 2846905174, class security
# No edges found for apartment 2846905174, class religion
# No edges found for apartment 2853744990, class veterinary
# No edges found for apartment 2840855632, class religion
# No edges found for apartment 2853744990, class religion
# No edges found for apartment 1586728319, class security
# [100/5000] apt=2863821536 -> OKNo edges found for apartment 1532868055, class veterinary
#
# No edges found for apartment 2749368574, class religion
# No edges found for apartment 1567675907, class food_and_drink
# No edges found for apartment 1532868055, class religion
# No edges found for apartment 1567675907, class religion
# No edges found for apartment 2844713456, class education_prim
# No edges found for apartment 2864703360, class religion
# No edges found for apartment 2844713456, class veterinary
# No edges found for apartment 2842230870, class food_and_drink_stores
# No edges found for apartment 2781278198, class education_prim
# No edges found for apartment 2781278198, class veterinary
# No edges found for apartment 2844713456, class arts_and_entertainment
# No edges found for apartment 2842230870, class food_and_drink
# No edges found for apartment 2844713456, class security
# No edges found for apartment 2844713456, class religion
# No edges found for apartment 2842230870, class security
# No edges found for apartment 1551903009, class education_prim
# No edges found for apartment 2842230870, class religion
# No edges found for apartment 1551903009, class veterinary
# No edges found for apartment 2781278198, class food_and_drink
# No edges found for apartment 2844713456, class education_sup
# No edges found for apartment 2781278198, class religion
# No edges found for apartment 1551903009, class food_and_drink
# No edges found for apartment 1551903009, class park_like
# No edges found for apartment 1551903009, class religion
# No edges found for apartment 2856766328, class veterinary
# No edges found for apartment 2769448840, class religion
# No edges found for apartment 2856660502, class veterinary
# No edges found for apartment 2856766328, class religion
# [101/5000] apt=1585327227 -> OK
# No edges found for apartment 2850864456, class veterinary
# No edges found for apartment 2856660502, class religion
# No edges found for apartment 2843785270, class education_prim
# No edges found for apartment 2843785270, class veterinary
# No edges found for apartment 2850864456, class food_and_drink
# No edges found for apartment 2838194698, class veterinary
# No edges found for apartment 2850864456, class religion
# No edges found for apartment 2843785270, class park_like
# No edges found for apartment 2862698572, class education_prim
# No edges found for apartment 2862698572, class veterinary
# No edges found for apartment 2843785270, class religion
# No edges found for apartment 2860623276, class education_prim
# No edges found for apartment 2838194698, class religion
# No edges found for apartment 2862698572, class park_like
# No edges found for apartment 2862698572, class religion
# No edges found for apartment 2860623276, class park_like
# No edges found for apartment 1532900469, class veterinary
# No edges found for apartment 2860623276, class religion
# No edges found for apartment 1532900469, class food_and_drink_stores
# No edges found for apartment 1590591687, class education_prim
# No edges found for apartment 1590591687, class veterinary
# No edges found for apartment 2770689584, class food_and_drink
# No edges found for apartment 1532900469, class food_and_drink
# No edges found for apartment 2808033366, class education_prim
# No edges found for apartment 1532900469, class religion
# No edges found for apartment 2808033366, class veterinary
# No edges found for apartment 1590591687, class park_like
# No edges found for apartment 1590591687, class religion
# No edges found for apartment 2858011378, class religion
# No edges found for apartment 2808033366, class food_and_drink
# No edges found for apartment 2808033366, class park_like
# [102/5000] apt=2860955756 -> OK
# No edges found for apartment 2808033366, class religion
# No edges found for apartment 2854373604, class religion
# No edges found for apartment 1561626509, class education_prim
# No edges found for apartment 1561626509, class veterinary
# No edges found for apartment 1539683571, class education_prim
# No edges found for apartment 1539683571, class veterinary
# No edges found for apartment 1561626509, class park_like
# No edges found for apartment 1570369455, class education_prim
# No edges found for apartment 1570369455, class veterinary
# No edges found for apartment 1561626509, class religion
# No edges found for apartment 1539683571, class park_like
# No edges found for apartment 1539683571, class religion
# No edges found for apartment 1570369455, class park_like
# No edges found for apartment 1570369455, class religion
# No edges found for apartment 1542135265, class religion
# No edges found for apartment 2793528022, class education_prim
# [103/5000] apt=2833909262 -> OK
# No edges found for apartment 1572102845, class veterinary
# No edges found for apartment 2793528022, class religion
# No edges found for apartment 1572102845, class religion
# No edges found for apartment 1584809283, class security
# No edges found for apartment 2771251586, class education_prim
# No edges found for apartment 2771251586, class veterinary
# No edges found for apartment 2864439584, class security
# No edges found for apartment 2853372866, class security
# No edges found for apartment 2771251586, class food_and_drink
# No edges found for apartment 1568607703, class education_prim
# No edges found for apartment 1568607703, class veterinary
# No edges found for apartment 1546253705, class education_prim
# No edges found for apartment 1546253705, class veterinary
# No edges found for apartment 2834993414, class security
# No edges found for apartment 1568607703, class park_like
# No edges found for apartment 1568607703, class religion
# No edges found for apartment 1546253705, class food_and_drink
# No edges found for apartment 2755259028, class security
# No edges found for apartment 2864017656, class education_prim
# No edges found for apartment 1584770419, class security
# No edges found for apartment 2864017656, class veterinary
# [104/5000] apt=1565879373 -> OK
# No edges found for apartment 2855375544, class veterinary
# No edges found for apartment 2864017656, class food_and_drink
# No edges found for apartment 2864017656, class park_like
# No edges found for apartment 1582467763, class park_like
# No edges found for apartment 2864017656, class religion
# No edges found for apartment 1582467763, class religion
# No edges found for apartment 2835446898, class education_prim
# No edges found for apartment 2835446898, class veterinary
# No edges found for apartment 2751272046, class education_prim
# No edges found for apartment 2855375544, class religion
# No edges found for apartment 1591095879, class education_prim
# No edges found for apartment 1591095879, class veterinary
# No edges found for apartment 2855388758, class security
# No edges found for apartment 2835446898, class park_like
# No edges found for apartment 2835446898, class security
# No edges found for apartment 2835446898, class religion
# No edges found for apartment 2751272046, class food_and_drink
# No edges found for apartment 2751272046, class park_like
# No edges found for apartment 2853852270, class security
# No edges found for apartment 2751272046, class religion
# No edges found for apartment 1584390353, class education_prim
# No edges found for apartment 1591095879, class park_like
# No edges found for apartment 1584390353, class veterinary
# No edges found for apartment 1583182655, class veterinary
# No edges found for apartment 1591095879, class religion
# No edges found for apartment 1584390353, class food_and_drink
# No edges found for apartment 1584390353, class park_like
# No edges found for apartment 1584390353, class religion
# No edges found for apartment 1583182655, class religion
# No edges found for apartment 1568543555, class veterinary
# No edges found for apartment 1588594471, class religion
# No edges found for apartment 1547650795, class education_prim
# No edges found for apartment 1584545209, class security
# No edges found for apartment 1568543555, class religion
# No edges found for apartment 1578369339, class security
# No edges found for apartment 1547650795, class food_and_drink
# No edges found for apartment 1547650795, class park_like
# No edges found for apartment 1540974537, class education_prim
# [105/5000] apt=2808855674 -> OK
# No edges found for apartment 1540974537, class veterinary
# No edges found for apartment 1547650795, class religion
# No edges found for apartment 2762474440, class education_prim
# No edges found for apartment 2762474440, class veterinary
# No edges found for apartment 1548098483, class security
# No edges found for apartment 2862826182, class education_prim
# No edges found for apartment 1540974537, class park_like
# No edges found for apartment 2762474440, class park_like
# No edges found for apartment 2862826182, class food_and_drink_stores
# No edges found for apartment 2762474440, class religion
# No edges found for apartment 1540974537, class religion
# No edges found for apartment 1543293451, class security
# No edges found for apartment 2862750452, class education_prim
# No edges found for apartment 1543293451, class religion
# No edges found for apartment 2858140816, class veterinary
# No edges found for apartment 2862750452, class food_and_drink_stores
# No edges found for apartment 1552345927, class education_prim
# No edges found for apartment 1552345927, class veterinary
# No edges found for apartment 1552345927, class food_and_drink_stores
# No edges found for apartment 1539683605, class security
# No edges found for apartment 1577332917, class education_prim
# No edges found for apartment 2826231924, class education_prim
# No edges found for apartment 2826231924, class veterinary
# No edges found for apartment 2863504954, class park_like
# No edges found for apartment 2863504954, class religion
# No edges found for apartment 2826231924, class food_and_drink
# No edges found for apartment 2826231924, class park_like
# No edges found for apartment 1577332917, class religion
# No edges found for apartment 2826231924, class religion
# No edges found for apartment 1550849305, class education_prim
# No edges found for apartment 1550849305, class veterinary
# No edges found for apartment 1550849305, class food_and_drink_stores
# No edges found for apartment 1583393209, class education_prim
# No edges found for apartment 1583393209, class veterinary
# No edges found for apartment 2779073950, class medical
# [106/5000] apt=1535122637 -> OK
# No edges found for apartment 2779073950, class education_prim
# No edges found for apartment 2779073950, class veterinary
# No edges found for apartment 2779073950, class food_and_drink_stores
# No edges found for apartment 1583393209, class park_like
# No edges found for apartment 2837286422, class education_prim
# No edges found for apartment 2833670730, class veterinary
# No edges found for apartment 2837286422, class veterinary
# No edges found for apartment 1583393209, class security
# No edges found for apartment 1583393209, class religion
# No edges found for apartment 2779073950, class food_and_drink
# No edges found for apartment 2837286422, class food_and_drink_stores
# No edges found for apartment 2833670730, class food_and_drink_stores
# No edges found for apartment 2779073950, class religion
# No edges found for apartment 1587781625, class religion
# No edges found for apartment 2833670730, class food_and_drink
# No edges found for apartment 2837286422, class food_and_drink
# No edges found for apartment 2837286422, class park_like
# No edges found for apartment 2837286422, class religion
# No edges found for apartment 2833670730, class religion
# No edges found for apartment 2749393902, class religion
# No edges found for apartment 1570995059, class veterinary
# No edges found for apartment 2864224472, class security
# No edges found for apartment 1570904601, class veterinary
# No edges found for apartment 2863488186, class veterinary
# No edges found for apartment 2861243468, class veterinary
# No edges found for apartment 1570995059, class education_sup
# No edges found for apartment 1570904601, class education_sup
# [107/5000] apt=2852469858 -> OK
# No edges found for apartment 2842158564, class veterinary
# No edges found for apartment 2846673128, class education_sup
# No edges found for apartment 2746546592, class food_and_drink
# No edges found for apartment 2746546592, class education_sup
# No edges found for apartment 2862676804, class veterinary
# No edges found for apartment 2862676804, class food_and_drink
# No edges found for apartment 1553197117, class religion
# No edges found for apartment 2861190914, class veterinary
# [108/5000] apt=2861240052 -> OK
# No edges found for apartment 2853385122, class veterinary
# No edges found for apartment 1591837239, class education_sup
# No edges found for apartment 1586805657, class veterinary
# No edges found for apartment 2853385122, class religion
# No edges found for apartment 2853385122, class education_sup
# No edges found for apartment 2811146066, class veterinary
# No edges found for apartment 1578400757, class veterinary
# No edges found for apartment 2863472770, class religion
# No edges found for apartment 1582548161, class religion
# [109/5000] apt=1590595795 -> OK
# No edges found for apartment 2863472770, class education_sup
# No edges found for apartment 2649296910, class park_like
# No edges found for apartment 1572631347, class veterinary
# No edges found for apartment 2811146066, class education_sup
# No edges found for apartment 1578400757, class education_sup
# No edges found for apartment 1561767059, class veterinary
# No edges found for apartment 1572631347, class religion
# No edges found for apartment 2843970054, class veterinary
# No edges found for apartment 2843970054, class food_and_drink_stores
# No edges found for apartment 1572631347, class education_sup
# No edges found for apartment 1587216699, class veterinary
# No edges found for apartment 2843970054, class food_and_drink
# No edges found for apartment 1567693027, class education_sup
# No edges found for apartment 1583311371, class veterinary
# [110/5000] apt=1580243627 -> OK
# No edges found for apartment 1582589265, class park_like
# No edges found for apartment 2846763836, class religion
# No edges found for apartment 2845613904, class sport_and_leisure
# No edges found for apartment 2853352794, class veterinary
# ...
# [1774/5000] apt=2737870676 -> OK
# [1775/5000] apt=1579749843 -> OK
# [1776/5000] apt=1578372197 -> OK
# [1777/5000] apt=1577608891 -> OK
# [1778/5000] apt=1542602213 -> OK
# [1779/5000] apt=1537153109 -> OK
# [1780/5000] apt=2841708512 -> OK
# [1781/5000] apt=2864787898 -> OK
# [1782/5000] apt=2862203570 -> OK
# [1783/5000] apt=2857721692 -> OK
# [1784/5000] apt=1551056427 -> OK
# [1785/5000] apt=2840472612 -> OK
# [1786/5000] apt=2842901738 -> OK
# [1787/5000] apt=1585267873 -> OK
# [1788/5000] apt=2841611432 -> OK
# [1789/5000] apt=2862653500 -> OK
# [1790/5000] apt=2859244478 -> OK
# [1791/5000] apt=2859152066 -> OK
# [1792/5000] apt=2845533776 -> OK
# [1793/5000] apt=2822462254 -> OK
# [1794/5000] apt=1557791329 -> OK
# [1795/5000] apt=2859710560 -> OK
# [1796/5000] apt=2852032026 -> OK
# [1797/5000] apt=1590936357 -> OK
# [1798/5000] apt=1566038673 -> OK
# [1799/5000] apt=2860313252 -> OK
# [1800/5000] apt=2860197166 -> OK
# [1801/5000] apt=2853371850 -> OK
# [1802/5000] apt=1584766005 -> OK
# [1803/5000] apt=2859074752 -> OK
# [1804/5000] apt=2831564710 -> OK
# [1805/5000] apt=2780806578 -> OK
# [1806/5000] apt=2746241210 -> OK
# [1807/5000] apt=2740616174 -> OK
# [1808/5000] apt=2737637354 -> OK
# [1809/5000] apt=1582550787 -> OK
# [1810/5000] apt=2724601798 -> OK
# [1811/5000] apt=1578746897 -> OK
# [1812/5000] apt=1574082721 -> OK
# [1813/5000] apt=2859240146 -> OK
# [1814/5000] apt=1571697199 -> OK
# [1815/5000] apt=2845532388 -> OK
# [1816/5000] apt=2857320746 -> OK
# [1817/5000] apt=2724642980 -> OK
# [1818/5000] apt=2843859044 -> OK
# [1819/5000] apt=2857268768 -> OK
# [1820/5000] apt=2855735302 -> OK
# [1821/5000] apt=2740581914 -> OK
# [1822/5000] apt=2836246652 -> OK
# [1823/5000] apt=2731965786 -> OK
# [1824/5000] apt=1589375505 -> OK
# [1825/5000] apt=2853983112 -> OK
# [1826/5000] apt=2859099770 -> OK
# [1827/5000] apt=2830727578 -> OK
# [1828/5000] apt=1558661757 -> OK
# [1829/5000] apt=2863938642 -> OK
# [1830/5000] apt=1549604519 -> OK
# [1831/5000] apt=1583326083 -> OK
# [1832/5000] apt=2851928118 -> OK
# [1833/5000] apt=1542613807 -> OK
# [1834/5000] apt=2838980562 -> OK
# [1835/5000] apt=1571507119 -> OK
# [1836/5000] apt=1590302017 -> OK
# [1837/5000] apt=1540467069 -> OK
# [1838/5000] apt=2857980094 -> OK
# [1839/5000] apt=2862242864 -> OK
# [1840/5000] apt=1543796731 -> OK
# [1841/5000] apt=2857254718 -> OK
# [1842/5000] apt=2859044956 -> OK
# [1843/5000] apt=2854216580 -> OK
# [1844/5000] apt=2852927568 -> OK
# [1845/5000] apt=2846415156 -> OK
# [1846/5000] apt=2851407030 -> OK
# [1847/5000] apt=2820331698 -> OK
# [1848/5000] apt=2820759784 -> OK
# [1849/5000] apt=2763622566 -> OK
# [1850/5000] apt=2758782560 -> OK
# [1851/5000] apt=2743973794 -> OK
# [1852/5000] apt=1589189839 -> OK
# [1853/5000] apt=1584518529 -> OK
# [1854/5000] apt=1584407481 -> OK
# [1855/5000] apt=1578424159 -> OK
# [1856/5000] apt=1547324833 -> OK
# [1857/5000] apt=1577622049 -> OK
# [1858/5000] apt=1582617347 -> OK
# [1859/5000] apt=1546596347 -> OK
# [1860/5000] apt=2839629020 -> OK
# [1861/5000] apt=2752619976 -> OK
# [1862/5000] apt=2850460774 -> OK
# [1863/5000] apt=1579469819 -> OK
# [1864/5000] apt=1587921139 -> OK
# [1865/5000] apt=2859242994 -> OK
# [1866/5000] apt=2853477750 -> OK
# [1867/5000] apt=2847346410 -> OK
# [1868/5000] apt=2784641562 -> OK
# [1869/5000] apt=2857075774 -> OK
# [1870/5000] apt=2853913038 -> OK
# [1871/5000] apt=2851557050 -> OK
# [1872/5000] apt=1590276955 -> OK
# [1873/5000] apt=1580864559 -> OK
# [1874/5000] apt=2859164484 -> OK
# [1875/5000] apt=2861575900 -> OK
# [1876/5000] apt=1546895359 -> OK
# [1877/5000] apt=2863717312 -> OK
# [1878/5000] apt=2848001294 -> OK
# [1879/5000] apt=1583932177 -> OK
# [1880/5000] apt=1583323975 -> OK
# [1881/5000] apt=2855781464 -> OK
# [1882/5000] apt=2814783778 -> OK
# [1883/5000] apt=1583326399 -> OK
# [1884/5000] apt=2850992780 -> OK
# [1885/5000] apt=2778808782 -> OK
# [1886/5000] apt=2747483878 -> OK
# [1887/5000] apt=1563976805 -> OK
# [1888/5000] apt=2849643828 -> OK
# [1889/5000] apt=1540634187 -> OK
# [1890/5000] apt=2837072288 -> OK
# [1891/5000] apt=2797428222 -> OK
# [1892/5000] apt=1582700331 -> OK
# [1893/5000] apt=1589998431 -> OK
# [1894/5000] apt=1576275017 -> OK
# [1895/5000] apt=1543293231 -> OK
# [1896/5000] apt=1573922573 -> OK
# [1897/5000] apt=2753208128 -> OK
# [1898/5000] apt=2826232206 -> OK
# [1899/5000] apt=1573331215 -> OK
# [1900/5000] apt=2821349056 -> OK
# [1901/5000] apt=2864040880 -> OK
# [1902/5000] apt=2863746770 -> OK
# [1903/5000] apt=2862138712 -> OK
# [1904/5000] apt=2862163648 -> OK
# [1905/5000] apt=2859218080 -> OK
# [1906/5000] apt=2857800444 -> OK
# [1907/5000] apt=2854618480 -> OK
# [1908/5000] apt=2844218568 -> OK
# [1909/5000] apt=2841891972 -> OK
# [1910/5000] apt=2836458250 -> OK
# [1911/5000] apt=2830316370 -> OK
# [1912/5000] apt=2816513908 -> OK
# [1913/5000] apt=2730055896 -> OK
# [1914/5000] apt=2649365258 -> OK
# [1915/5000] apt=1591202199 -> OK
# [1916/5000] apt=1579791177 -> OK
# [1917/5000] apt=1545814097 -> OK
# [1918/5000] apt=1534051491 -> OK
# [1919/5000] apt=2863437464 -> OK
# [1920/5000] apt=1586701447 -> OK
# [1921/5000] apt=1583335981 -> OK
# [1922/5000] apt=2861601730 -> OK
# [1923/5000] apt=2861640700 -> OK
# [1924/5000] apt=1584327211 -> OK
# [1925/5000] apt=1578320505 -> OK
# [1926/5000] apt=1549659911 -> OK
# [1927/5000] apt=1589439735 -> OK
# [1928/5000] apt=1547123819 -> OK
# [1929/5000] apt=2816936234 -> OK
# [1930/5000] apt=1578784367 -> OK
# [1931/5000] apt=2830578040 -> OK
# [1932/5000] apt=2859203254 -> OK
# [1933/5000] apt=2862013140 -> OK
# [1934/5000] apt=2849796166 -> OK
# [1935/5000] apt=1578712695 -> OK
# [1936/5000] apt=1570931985 -> OK
# [1937/5000] apt=2856637944 -> OK
# [1938/5000] apt=1583003933 -> OK
# [1939/5000] apt=2863847856 -> OK
# [1940/5000] apt=2858623840 -> OK
# [1941/5000] apt=2800191510 -> OK
# [1942/5000] apt=2797681822 -> OK
# [1943/5000] apt=2759410802 -> OK
# [1944/5000] apt=1578229557 -> OK
# [1945/5000] apt=2859252412 -> OK
# [1946/5000] apt=2824933216 -> OK
# [1947/5000] apt=1574861555 -> OK
# [1948/5000] apt=2732066094 -> OK
# [1949/5000] apt=2844724312 -> OK
# [1950/5000] apt=2859668444 -> OK
# [1951/5000] apt=2766745416 -> OK
# [1952/5000] apt=1591102249 -> OK
# [1953/5000] apt=1589162255 -> OK
# [1954/5000] apt=2746201844 -> OK
# [1955/5000] apt=1584441767 -> OK
# [1956/5000] apt=1549560961 -> OK
# [1957/5000] apt=1548822979 -> OK
# [1958/5000] apt=2857595718 -> OK
# [1959/5000] apt=2832407318 -> OK
# [1960/5000] apt=1590315453 -> OK
# [1961/5000] apt=2848757620 -> OK
# [1962/5000] apt=2769420908 -> OK
# [1963/5000] apt=1583336431 -> OK
# [1964/5000] apt=1572505429 -> OK
# [1965/5000] apt=2722875018 -> OK
# [1966/5000] apt=1550015051 -> OK
# [1967/5000] apt=1584429381 -> OK
# [1968/5000] apt=1533751699 -> OK
# [1969/5000] apt=2857733558 -> OK
# [1970/5000] apt=2857752720 -> OK
# [1971/5000] apt=1565264175 -> OK
# [1972/5000] apt=1548201237 -> OK
# [1973/5000] apt=2846738326 -> OK
# [1974/5000] apt=2852477738 -> OK
# [1975/5000] apt=2847310068 -> OK
# [1976/5000] apt=2846877076 -> OK
# [1977/5000] apt=2837875052 -> OK
# [1978/5000] apt=2838940768 -> OK
# [1979/5000] apt=2790338926 -> OK
# [1980/5000] apt=1591777057 -> OK
# [1981/5000] apt=1585137755 -> OK
# [1982/5000] apt=1584778193 -> OK
# [1983/5000] apt=2857856468 -> OK
# [1984/5000] apt=2849184656 -> OK
# [1985/5000] apt=1569144759 -> OK
# [1986/5000] apt=2861902124 -> OK
# [1987/5000] apt=1591764107 -> OK
# [1988/5000] apt=2836005346 -> OK
# [1989/5000] apt=1583927691 -> OK
# [1990/5000] apt=1583285143 -> OK
# [1991/5000] apt=1549237101 -> OK
# [1992/5000] apt=1542766261 -> OK
# [1993/5000] apt=1578320479 -> OK
# [1994/5000] apt=1582484947 -> OK
# [1995/5000] apt=1551459573 -> OK
# [1996/5000] apt=1572647417 -> OK
# [1997/5000] apt=2771077116 -> OK
# [1998/5000] apt=1589597913 -> OK
# [1999/5000] apt=1584388871 -> OK
# [2000/5000] apt=2860145110 -> OK
# [2001/5000] apt=1591532485 -> OK
# [2002/5000] apt=2834073686 -> OK
# [2003/5000] apt=2845209370 -> OK
# [2004/5000] apt=2803833358 -> OK
# [2005/5000] apt=1590701963 -> OK
# [2006/5000] apt=1590285551 -> OK
# [2007/5000] apt=1588491137 -> OK
# [2008/5000] apt=1580340397 -> OK
# [2009/5000] apt=1578523499 -> OK
# [2010/5000] apt=1552420803 -> OK
# [2011/5000] apt=2818363802 -> OK
# [2012/5000] apt=1591298651 -> OK
# [2013/5000] apt=2812946096 -> OK
# [2014/5000] apt=2850137410 -> OK
# [2015/5000] apt=2845689052 -> OK
# [2016/5000] apt=1586779463 -> OK
# [2017/5000] apt=1583338871 -> OK
# [2018/5000] apt=2853412212 -> OK
# [2019/5000] apt=1546556551 -> OK
# [2020/5000] apt=1580100211 -> OK
# [2021/5000] apt=2847887352 -> OK
# [2022/5000] apt=1585110461 -> OK
# [2023/5000] apt=2854307326 -> OK
# [2024/5000] apt=2818350880 -> OK
# [2025/5000] apt=2857739948 -> OK
# [2026/5000] apt=1560378847 -> OK
# [2027/5000] apt=2854927502 -> OK
# [2028/5000] apt=2862707848 -> OK
# [2029/5000] apt=2852250876 -> OK
# [2030/5000] apt=2848713744 -> OK
# [2031/5000] apt=2833850578 -> OK
# [2032/5000] apt=2837871652 -> OK
# [2033/5000] apt=2830683716 -> OK
# [2034/5000] apt=2831556034 -> OK
# [2035/5000] apt=1555783165 -> OK
# [2036/5000] apt=1555757907 -> OK
# [2037/5000] apt=2811582906 -> OK
# [2038/5000] apt=2848726200 -> OK
# [2039/5000] apt=2837150618 -> OK
# [2040/5000] apt=2802188314 -> OK
# [2041/5000] apt=2732969528 -> OK
# [2042/5000] apt=2859110018 -> OK
# [2043/5000] apt=2843923724 -> OK
# [2044/5000] apt=1547208457 -> OK
# [2045/5000] apt=2861561618 -> OK
# [2046/5000] apt=2776142324 -> OK
# [2047/5000] apt=2848752544 -> OK
# [2048/5000] apt=1569297057 -> OK
# [2049/5000] apt=2738717778 -> OK
# [2050/5000] apt=2801918902 -> OK
# [2051/5000] apt=2742294818 -> OK
# [2052/5000] apt=2860884190 -> OK
# [2053/5000] apt=2830702182 -> OK
# [2054/5000] apt=2859088142 -> OK
# [2055/5000] apt=2765175106 -> OK
# [2056/5000] apt=1588235613 -> OK
# [2057/5000] apt=1573698615 -> OK
# [2058/5000] apt=2841099918 -> OK
# [2059/5000] apt=2861471544 -> OK
# [2060/5000] apt=1585736495 -> OK
# [2061/5000] apt=1583300707 -> OK
# [2062/5000] apt=1571372057 -> OK
# [2063/5000] apt=2796292744 -> OK
# [2064/5000] apt=2863584756 -> OK
# [2065/5000] apt=1580843381 -> OK
# [2066/5000] apt=2844338558 -> OK
# [2067/5000] apt=1556801457 -> OK
# [2068/5000] apt=2861719168 -> OK
# [2069/5000] apt=2861101108 -> OK
# [2070/5000] apt=2863939360 -> OK
# [2071/5000] apt=2854823896 -> OK
# [2072/5000] apt=2860351680 -> OK
# [2073/5000] apt=2849404608 -> OK
# [2074/5000] apt=2844092452 -> OK
# [2075/5000] apt=1588172383 -> OK
# [2076/5000] apt=1583285759 -> OK
# [2077/5000] apt=1583764357 -> OK
# [2078/5000] apt=1575091139 -> OK
# [2079/5000] apt=1580070249 -> OK
# [2080/5000] apt=1571679615 -> OK
# [2081/5000] apt=1534663259 -> OK
# [2082/5000] apt=2835992406 -> OK
# [2083/5000] apt=2859139592 -> OK
# [2084/5000] apt=2853701660 -> OK
# [2085/5000] apt=2830676564 -> OK
# [2086/5000] apt=2859482236 -> OK
# [2087/5000] apt=2860861264 -> OK
# [2088/5000] apt=1588710257 -> OK
# [2089/5000] apt=2859522238 -> OK
# [2090/5000] apt=2857385806 -> OK
# [2091/5000] apt=2848705752 -> OK
# [2092/5000] apt=2853717438 -> OK
# [2093/5000] apt=2844217368 -> OK
# [2094/5000] apt=2838118762 -> OK
# [2095/5000] apt=2837871692 -> OK
# [2096/5000] apt=1578398123 -> OK
# [2097/5000] apt=1577239113 -> OK
# [2098/5000] apt=1559852259 -> OK
# [2099/5000] apt=2859161728 -> OK
# [2100/5000] apt=2852137504 -> OK
# [2101/5000] apt=2726424290 -> OK
# [2102/5000] apt=2812311676 -> OK
# [2103/5000] apt=2849479604 -> OK
# [2104/5000] apt=2840196196 -> OK
# [2105/5000] apt=1586805149 -> OK
# [2106/5000] apt=1570699155 -> OK
# [2107/5000] apt=2755339648 -> OK
# [2108/5000] apt=1588785017 -> OK
# [2109/5000] apt=2862063728 -> OK
# [2110/5000] apt=2807348910 -> OK
# [2111/5000] apt=2861986892 -> OK
# [2112/5000] apt=2732932136 -> OK
# [2113/5000] apt=1564620051 -> OK
# [2114/5000] apt=1554036209 -> OK
# [2115/5000] apt=2851883546 -> OK
# [2116/5000] apt=2744020074 -> OK
# [2117/5000] apt=2856826652 -> OK
# [2118/5000] apt=2824850776 -> OK
# [2119/5000] apt=1583274875 -> OK
# [2120/5000] apt=1539899927 -> OK
# [2121/5000] apt=2854998900 -> OK
# [2122/5000] apt=2859110016 -> OK
# [2123/5000] apt=2856041190 -> OK
# [2124/5000] apt=2803461432 -> OK
# [2125/5000] apt=1578203605 -> OK
# [2126/5000] apt=2802042144 -> OK
# [2127/5000] apt=2839434572 -> OK
# [2128/5000] apt=1571838965 -> OK
# [2129/5000] apt=2862560116 -> OK
# [2130/5000] apt=1586857559 -> OK
# [2131/5000] apt=2817616558 -> OK
# [2132/5000] apt=2848700464 -> OK
# [2133/5000] apt=2853359892 -> OK
# [2134/5000] apt=1572438809 -> OK
# [2135/5000] apt=2846784130 -> OK
# [2136/5000] apt=2855994610 -> OK
# [2137/5000] apt=2848718490 -> OK
# [2138/5000] apt=2842885346 -> OK
# [2139/5000] apt=2854074200 -> OK
# [2140/5000] apt=1582552161 -> OK
# [2141/5000] apt=1557397057 -> OK
# [2142/5000] apt=1583667265 -> OK
# [2143/5000] apt=1580463335 -> OK
# [2144/5000] apt=1571491275 -> OK
# [2145/5000] apt=2859136066 -> OK
# [2146/5000] apt=2862230658 -> OK
# [2147/5000] apt=1592000809 -> OK
# [2148/5000] apt=2755258788 -> OK
# [2149/5000] apt=1572270667 -> OK
# [2150/5000] apt=2860795282 -> OK
# [2151/5000] apt=1586754163 -> OK
# [2152/5000] apt=1584736009 -> OK
# [2153/5000] apt=1572070103 -> OK
# [2154/5000] apt=1546420109 -> OK
# [2155/5000] apt=1567374339 -> OK
# [2156/5000] apt=2864189212 -> OK
# [2157/5000] apt=2855587876 -> OK
# [2158/5000] apt=2844515032 -> OK
# [2159/5000] apt=1589965971 -> OK
# [2160/5000] apt=2808758754 -> OK
# [2161/5000] apt=2732063086 -> OK
# [2162/5000] apt=1580789659 -> OK
# [2163/5000] apt=1586701621 -> OK
# [2164/5000] apt=2848778314 -> OK
# [2165/5000] apt=2828602574 -> OK
# [2166/5000] apt=2755172952 -> OK
# [2167/5000] apt=1572142531 -> OK
# [2168/5000] apt=1549156973 -> OK
# [2169/5000] apt=2860519994 -> OK
# [2170/5000] apt=2858384354 -> OK
# [2171/5000] apt=1570396709 -> OK
# [2172/5000] apt=2810125128 -> OK
# [2173/5000] apt=2798930960 -> OK
# [2174/5000] apt=2781904904 -> OK
# [2175/5000] apt=2749423398 -> OK
# [2176/5000] apt=1589943109 -> OK
# [2177/5000] apt=1578294401 -> OK
# [2178/5000] apt=1582610135 -> OK
# [2179/5000] apt=1570435615 -> OK
# [2180/5000] apt=2755166870 -> OK
# [2181/5000] apt=2860151792 -> OK
# [2182/5000] apt=2859152136 -> OK
# [2183/5000] apt=2859136462 -> OK
# [2184/5000] apt=1584766101 -> OK
# [2185/5000] apt=2859179244 -> OK
# [2186/5000] apt=2858054846 -> OK
# [2187/5000] apt=1578385373 -> OK
# [2188/5000] apt=1584586889 -> OK
# [2189/5000] apt=2855646760 -> OK
# [2190/5000] apt=1538405411 -> OK
# [2191/5000] apt=1571946367 -> OK
# [2192/5000] apt=2859265310 -> OK
# [2193/5000] apt=2859160522 -> OK
# [2194/5000] apt=1575645015 -> OK
# [2195/5000] apt=2863848914 -> OK
# [2196/5000] apt=1575642615 -> OK
# [2197/5000] apt=1578229523 -> OK
# [2198/5000] apt=2838293346 -> OK
# [2199/5000] apt=2851863974 -> OK
# [2200/5000] apt=1551029227 -> OK
# [2201/5000] apt=2794496396 -> OK
# [2202/5000] apt=2848700402 -> OK
# [2203/5000] apt=2849559958 -> OK
# [2204/5000] apt=2860287306 -> OK
# [2205/5000] apt=2847462950 -> OK
# [2206/5000] apt=1586707705 -> OK
# [2207/5000] apt=2841252382 -> OK
# [2208/5000] apt=2849032656 -> OK
# [2209/5000] apt=1587152099 -> OK
# [2210/5000] apt=2859140380 -> OK
# [2211/5000] apt=2826573664 -> OK
# [2212/5000] apt=2838025916 -> OK
# [2213/5000] apt=1592710387 -> OK
# [2214/5000] apt=1542141819 -> OK
# [2215/5000] apt=1572144777 -> OK
# [2216/5000] apt=2749385588 -> OK
# [2217/5000] apt=2863610158 -> OK
# [2218/5000] apt=1590709823 -> OK
# [2219/5000] apt=2780473028 -> OK
# [2220/5000] apt=1578242615 -> OK
# [2221/5000] apt=1591050523 -> OK
# [2222/5000] apt=1569374505 -> OK
# [2223/5000] apt=1533002925 -> OK
# [2224/5000] apt=1483422501 -> OK
# [2225/5000] apt=1546523015 -> OK
# [2226/5000] apt=1586667555 -> OK
# [2227/5000] apt=2864285802 -> OK
# [2228/5000] apt=2854490866 -> OK
# [2229/5000] apt=2837861750 -> OK
# [2230/5000] apt=2825469818 -> OK
# [2231/5000] apt=2809741722 -> OK
# [2232/5000] apt=2860233646 -> OK
# [2233/5000] apt=2824960536 -> OK
# [2234/5000] apt=1562826547 -> OK
# [2235/5000] apt=1583785931 -> OK
# [2236/5000] apt=1571663005 -> OK
# [2237/5000] apt=2848700172 -> OK
# [2238/5000] apt=1591396775 -> OK
# [2239/5000] apt=1588658477 -> OK
# [2240/5000] apt=1533690187 -> OK
# [2241/5000] apt=2853723658 -> OK
# [2242/5000] apt=2861070954 -> OK
# [2243/5000] apt=2860723214 -> OK
# [2244/5000] apt=2858148590 -> OK
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 19
#      17             all_graphs[apt_id] = graphs
#      18             with open(OUTPUT_FILE, 'wb') as f:
# ---> 19                 pickle.dump(all_graphs, f)
#      22 print(f"✅ Batch finished in {time.time()-start_batch:.2f}s. Total saved so far: {len(all_graphs)}")
#
# KeyboardInterrupt:

# %%
N_LAST = 10 # change as needed
import pickle


with open(OUTPUT_FILE, 'rb') as f:
    saved: dict[int, dict[str, Data | None]] = pickle.load(f)


print(f"Total saved apartments: {len(saved)}")


# Dicts preserve insertion order; take the last N inserted IDs
last_ids = list(saved.keys())[-N_LAST:]
print(f"Inspecting last {len(last_ids)} apartments (most recent first shown below):")


for aid in last_ids:
    graphs = saved[aid]
    # sanity: ensure we have all 11 class keys (some may be None by design)
    missing_keys = [c for c in CLASSES if c not in graphs]
    none_cnt = sum(1 for v in graphs.values() if v is None)
    print(f"Apartment {aid}: classes={len(graphs)} (missing_keys={missing_keys}, none={none_cnt})")
    for cls in CLASSES:
        g = graphs.get(cls)
        if g is None:
            print(f" - {cls:<24} -> None")
        else:
            print(f" - {cls:<24} -> x={tuple(g.x.shape)}, edges={tuple(g.edge_index.shape)}, attr={tuple(g.edge_attr.shape)}")
# Out:
# Total saved apartments: 150
# Inspecting last 10 apartments (most recent first shown below):
# Apartment 2829175322: classes=11 (missing_keys=[], none=0)
#  - sport_and_leisure        -> x=(79, 4), edges=(2, 78), attr=(78, 1)
#  - medical                  -> x=(13, 4), edges=(2, 12), attr=(12, 1)
#  - education_prim           -> x=(8, 4), edges=(2, 7), attr=(7, 1)
#  - veterinary               -> x=(5, 4), edges=(2, 4), attr=(4, 1)
#  - food_and_drink_stores    -> x=(15, 4), edges=(2, 14), attr=(14, 1)
#  - arts_and_entertainment   -> x=(12, 4), edges=(2, 11), attr=(11, 1)
#  - food_and_drink           -> x=(8, 4), edges=(2, 7), attr=(7, 1)
#  - park_like                -> x=(7, 4), edges=(2, 6), attr=(6, 1)
#  - security                 -> x=(6, 4), edges=(2, 5), attr=(5, 1)
#  - religion                 -> x=(3, 4), edges=(2, 2), attr=(2, 1)
#  - education_sup            -> x=(13, 4), edges=(2, 12), attr=(12, 1)
# Apartment 2856021976: classes=11 (missing_keys=[], none=0)
#  - sport_and_leisure        -> x=(8, 4), edges=(2, 7), attr=(7, 1)
#  - medical                  -> x=(16, 4), edges=(2, 15), attr=(15, 1)
#  - education_prim           -> x=(15, 4), edges=(2, 14), attr=(14, 1)
#  - veterinary               -> x=(5, 4), edges=(2, 4), attr=(4, 1)
#  - food_and_drink_stores    -> x=(16, 4), edges=(2, 15), attr=(15, 1)
#  - arts_and_entertainment   -> x=(10, 4), edges=(2, 9), attr=(9, 1)
#  - food_and_drink           -> x=(13, 4), edges=(2, 12), attr=(12, 1)
#  - park_like                -> x=(5, 4), edges=(2, 4), attr=(4, 1)
#  - security                 -> x=(9, 4), edges=(2, 8), attr=(8, 1)
#  - religion                 -> x=(6, 4), edges=(2, 5), attr=(5, 1)
#  - education_sup            -> x=(63, 4), edges=(2, 62), attr=(62, 1)
# Apartment 1588355711: classes=11 (missing_keys=[], none=0)
#  - sport_and_leisure        -> x=(11, 4), edges=(2, 10), attr=(10, 1)
#  - medical                  -> x=(6, 4), edges=(2, 5), attr=(5, 1)
#  - education_prim           -> x=(6, 4), edges=(2, 5), attr=(5, 1)
#  - veterinary               -> x=(3, 4), edges=(2, 2), attr=(2, 1)
#  - food_and_drink_stores    -> x=(12, 4), edges=(2, 11), attr=(11, 1)
#  - arts_and_entertainment   -> x=(11, 4), edges=(2, 10), attr=(10, 1)
#  - food_and_drink           -> x=(10, 4), edges=(2, 9), attr=(9, 1)
#  - park_like                -> x=(2, 4), edges=(2, 1), attr=(1, 1)
#  - security                 -> x=(3, 4), edges=(2, 2), attr=(2, 1)
#  - religion                 -> x=(3, 4), edges=(2, 2), attr=(2, 1)
#  - education_sup            -> x=(4, 4), edges=(2, 3), attr=(3, 1)
# Apartment 2830643838: classes=11 (missing_keys=[], none=0)
#  - sport_and_leisure        -> x=(7, 4), edges=(2, 6), attr=(6, 1)
#  - medical                  -> x=(22, 4), edges=(2, 21), attr=(21, 1)
#  - education_prim           -> x=(13, 4), edges=(2, 12), attr=(12, 1)
#  - veterinary               -> x=(4, 4), edges=(2, 3), attr=(3, 1)
#  - food_and_drink_stores    -> x=(13, 4), edges=(2, 12), attr=(12, 1)
#  - arts_and_entertainment   -> x=(10, 4), edges=(2, 9), attr=(9, 1)
#  - food_and_drink           -> x=(5, 4), edges=(2, 4), attr=(4, 1)
#  - park_like                -> x=(10, 4), edges=(2, 9), attr=(9, 1)
#  - security                 -> x=(7, 4), edges=(2, 6), attr=(6, 1)
#  - religion                 -> x=(3, 4), edges=(2, 2), attr=(2, 1)
#  - education_sup            -> x=(19, 4), edges=(2, 18), attr=(18, 1)
# Apartment 2837274352: classes=11 (missing_keys=[], none=1)
#  - sport_and_leisure        -> x=(14, 4), edges=(2, 13), attr=(13, 1)
#  - medical                  -> x=(13, 4), edges=(2, 12), attr=(12, 1)
#  - education_prim           -> x=(3, 4), edges=(2, 2), attr=(2, 1)
#  - veterinary               -> x=(3, 4), edges=(2, 2), attr=(2, 1)
#  - food_and_drink_stores    -> x=(6, 4), edges=(2, 5), attr=(5, 1)
#  - arts_and_entertainment   -> x=(8, 4), edges=(2, 7), attr=(7, 1)
#  - food_and_drink           -> x=(22, 4), edges=(2, 21), attr=(21, 1)
#  - park_like                -> x=(2, 4), edges=(2, 1), attr=(1, 1)
#  - security                 -> x=(3, 4), edges=(2, 2), attr=(2, 1)
#  - religion                 -> None
#  - education_sup            -> x=(6, 4), edges=(2, 5), attr=(5, 1)
# Apartment 2854380246: classes=11 (missing_keys=[], none=0)
#  - sport_and_leisure        -> x=(16, 4), edges=(2, 15), attr=(15, 1)
#  - medical                  -> x=(37, 4), edges=(2, 36), attr=(36, 1)
#  - education_prim           -> x=(17, 4), edges=(2, 16), attr=(16, 1)
#  - veterinary               -> x=(3, 4), edges=(2, 2), attr=(2, 1)
#  - food_and_drink_stores    -> x=(25, 4), edges=(2, 24), attr=(24, 1)
#  - arts_and_entertainment   -> x=(17, 4), edges=(2, 16), attr=(16, 1)
#  - food_and_drink           -> x=(11, 4), edges=(2, 10), attr=(10, 1)
#  - park_like                -> x=(3, 4), edges=(2, 2), attr=(2, 1)
#  - security                 -> x=(5, 4), edges=(2, 4), attr=(4, 1)
#  - religion                 -> x=(4, 4), edges=(2, 3), attr=(3, 1)
#  - education_sup            -> x=(31, 4), edges=(2, 30), attr=(30, 1)
# Apartment 2857109590: classes=11 (missing_keys=[], none=0)
#  - sport_and_leisure        -> x=(14, 4), edges=(2, 13), attr=(13, 1)
#  - medical                  -> x=(23, 4), edges=(2, 22), attr=(22, 1)
#  - education_prim           -> x=(10, 4), edges=(2, 9), attr=(9, 1)
#  - veterinary               -> x=(3, 4), edges=(2, 2), attr=(2, 1)
#  - food_and_drink_stores    -> x=(17, 4), edges=(2, 16), attr=(16, 1)
#  - arts_and_entertainment   -> x=(15, 4), edges=(2, 14), attr=(14, 1)
#  - food_and_drink           -> x=(17, 4), edges=(2, 16), attr=(16, 1)
#  - park_like                -> x=(5, 4), edges=(2, 4), attr=(4, 1)
#  - security                 -> x=(5, 4), edges=(2, 4), attr=(4, 1)
#  - religion                 -> x=(6, 4), edges=(2, 5), attr=(5, 1)
#  - education_sup            -> x=(4, 4), edges=(2, 3), attr=(3, 1)
# Apartment 2843702078: classes=11 (missing_keys=[], none=0)
#  - sport_and_leisure        -> x=(116, 4), edges=(2, 115), attr=(115, 1)
#  - medical                  -> x=(75, 4), edges=(2, 74), attr=(74, 1)
#  - education_prim           -> x=(13, 4), edges=(2, 12), attr=(12, 1)
#  - veterinary               -> x=(4, 4), edges=(2, 3), attr=(3, 1)
#  - food_and_drink_stores    -> x=(33, 4), edges=(2, 32), attr=(32, 1)
#  - arts_and_entertainment   -> x=(36, 4), edges=(2, 35), attr=(35, 1)
#  - food_and_drink           -> x=(19, 4), edges=(2, 18), attr=(18, 1)
#  - park_like                -> x=(5, 4), edges=(2, 4), attr=(4, 1)
#  - security                 -> x=(5, 4), edges=(2, 4), attr=(4, 1)
#  - religion                 -> x=(2, 4), edges=(2, 1), attr=(1, 1)
#  - education_sup            -> x=(99, 4), edges=(2, 98), attr=(98, 1)
# Apartment 2850792272: classes=11 (missing_keys=[], none=0)
#  - sport_and_leisure        -> x=(28, 4), edges=(2, 27), attr=(27, 1)
#  - medical                  -> x=(7, 4), edges=(2, 6), attr=(6, 1)
#  - education_prim           -> x=(7, 4), edges=(2, 6), attr=(6, 1)
#  - veterinary               -> x=(2, 4), edges=(2, 1), attr=(1, 1)
#  - food_and_drink_stores    -> x=(4, 4), edges=(2, 3), attr=(3, 1)
#  - arts_and_entertainment   -> x=(4, 4), edges=(2, 3), attr=(3, 1)
#  - food_and_drink           -> x=(3, 4), edges=(2, 2), attr=(2, 1)
#  - park_like                -> x=(11, 4), edges=(2, 10), attr=(10, 1)
#  - security                 -> x=(6, 4), edges=(2, 5), attr=(5, 1)
#  - religion                 -> x=(2, 4), edges=(2, 1), attr=(1, 1)
#  - education_sup            -> x=(4, 4), edges=(2, 3), attr=(3, 1)
# Apartment 1592386375: classes=11 (missing_keys=[], none=0)
#  - sport_and_leisure        -> x=(27, 4), edges=(2, 26), attr=(26, 1)
#  - medical                  -> x=(83, 4), edges=(2, 82), attr=(82, 1)
#  - education_prim           -> x=(17, 4), edges=(2, 16), attr=(16, 1)
#  - veterinary               -> x=(9, 4), edges=(2, 8), attr=(8, 1)
#  - food_and_drink_stores    -> x=(105, 4), edges=(2, 104), attr=(104, 1)
#  - arts_and_entertainment   -> x=(134, 4), edges=(2, 133), attr=(133, 1)
#  - food_and_drink           -> x=(146, 4), edges=(2, 145), attr=(145, 1)
#  - park_like                -> x=(16, 4), edges=(2, 15), attr=(15, 1)
#  - security                 -> x=(27, 4), edges=(2, 26), attr=(26, 1)
#  - religion                 -> x=(10, 4), edges=(2, 9), attr=(9, 1)
#  - education_sup            -> x=(262, 4), edges=(2, 261), attr=(261, 1)
