# %%
# Cell 1 — Imports & Config
import os, time, pickle, random
import pandas as pd
import numpy as np
import torch
from torch_geometric.data import Data
from neo4j import GraphDatabase
from neo4j.exceptions import ServiceUnavailable, TransientError
from concurrent.futures import ThreadPoolExecutor, as_completed

# Neo4j connection
NEO4J_URI = "bolt://localhost:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "12345678"
DATABASE = "neo4jads"

# Radii per category (meters)
RADII = {"CERCA_DE_CAT1": 600.0, "CERCA_DE_CAT2": 1200.0, "CERCA_DE_CAT3": 2400.0}

# Classes (11)
CLASSES = [
'sport_and_leisure','medical','education_prim','veterinary','food_and_drink_stores',
'arts_and_entertainment','food_and_drink','park_like','security','religion','education_sup'
]

# %%
# Cell 2 — Cypher queries (now returns BOTH raw meters and normalized weight)
NODE_QUERY = """
MATCH (d:Departamento {id:$apt_id})
RETURN elementId(d) AS id, 'Departamento' AS label,
       d.id AS apt_id, d.latitude AS lat, d.longitude AS lon, null AS cat
UNION
MATCH (d:Departamento {id:$apt_id})-[:CERCA_DE_CAT1|CERCA_DE_CAT2|CERCA_DE_CAT3]->(p:POI)
WHERE p.class = $class
RETURN elementId(p) AS id, 'POI' AS label,
       null AS apt_id, null AS lat, null AS lon, p.cat AS cat
"""

REL_QUERY = """
MATCH (d:Departamento {id:$apt_id})-[r:CERCA_DE_CAT1|CERCA_DE_CAT2|CERCA_DE_CAT3]->(p:POI)
WHERE p.class = $class
WITH elementId(d) AS source, elementId(p) AS target, type(r) AS t, r.distancia_metros AS dist
WITH source, target, dist,
  CASE t
    WHEN 'CERCA_DE_CAT1' THEN CASE WHEN 1.0 - dist / $r_cat1 > 0.001 THEN 1.0 - dist / $r_cat1 ELSE 0.001 END
    WHEN 'CERCA_DE_CAT2' THEN CASE WHEN 1.0 - dist / $r_cat2 > 0.001 THEN 1.0 - dist / $r_cat2 ELSE 0.001 END
    ELSE CASE WHEN 1.0 - dist / $r_cat3 > 0.001 THEN 1.0 - dist / $r_cat3 ELSE 0.001 END
  END AS weight
RETURN source, target, dist, weight
"""

# %%
# Cell 3 — Export function (session-aware, stores meters + normalized weight)
def export_apartment_class_graph(apt_id: int, class_name: str, session=None) -> Data | None:
    """Return PyG Data for (apt × class), or None if no nodes/edges.
    edge_attr  -> raw distance in meters (float, shape [E, 1])
    edge_weight-> normalized weight in [0.001, 1] (float, shape [E, 1])
    """
    # If no session provided, open a temporary one
    if session is None:
        driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
        try:
            with driver.session(database=DATABASE) as s:
                return export_apartment_class_graph(apt_id, class_name, session=s)
        finally:
            driver.close()

    # --- Nodes
    nodes = session.run(NODE_QUERY, {"apt_id": apt_id, "class": class_name}).data()
    if not nodes:
        return None
    node_df = pd.DataFrame(nodes)
    id_map = {nid: i for i, nid in enumerate(node_df["id"].tolist())}

    # --- Edges
    edges = session.run(
        REL_QUERY,
        {
            "apt_id": apt_id, "class": class_name,
            "r_cat1": RADII["CERCA_DE_CAT1"],
            "r_cat2": RADII["CERCA_DE_CAT2"],
            "r_cat3": RADII["CERCA_DE_CAT3"],
        },
    ).data()
    if not edges:
        # No POIs for this class: return None (we’ll store None in the shard)
        return None
    edge_df = pd.DataFrame(edges)  # columns: source, target, dist, weight

    # Remap to local indices
    edge_index = torch.tensor([
        [id_map[s] for s in edge_df["source"]],
        [id_map[t] for t in edge_df["target"]],
    ], dtype=torch.long)

    # --- Edge attributes
    edge_attr_dist = torch.tensor(edge_df["dist"].values, dtype=torch.float).unsqueeze(1)    # meters
    edge_weight    = torch.tensor(edge_df["weight"].values, dtype=torch.float).unsqueeze(1)  # normalized

    # --- Node features
    feats: list[list[float]] = []
    for _, row in node_df.iterrows():
        if row["label"] == "Departamento":
            feats.append([1.0, 0.0, 0.0, 0.0])  # [is_apartment, cat1, cat2, cat3]
        else:
            onehot = [0.0, 0.0, 0.0, 0.0]
            cat_val = row.get("cat")
            if cat_val is not None:
                try:
                    idx = int(cat_val)
                    if 0 <= idx < 4:
                        onehot[idx] = 1.0
                except (ValueError, TypeError):
                    pass
            feats.append(onehot)

    x = torch.tensor(np.array(feats), dtype=torch.float)

    # Keep meters in edge_attr (baseline will use it), and store weight separately
    return Data(
        x=x,
        edge_index=edge_index,
        edge_attr=edge_attr_dist,   # RAW METERS
        edge_weight=edge_weight,    # NORMALIZED WEIGHT (for future GNN use)
        apt_id=apt_id,
        poi_class=class_name
    )

# %%
# Cell 4 - Pickle helpers (no .bak) ---
def safe_load_pickle(path: str) -> dict:
    import os, pickle
    if not os.path.exists(path) or os.path.getsize(path) == 0:
        print(f"[warn] {path} missing/empty; starting fresh.")
        return {}
    try:
        with open(path, "rb") as f:
            return pickle.load(f)
    except (EOFError, pickle.UnpicklingError) as e:
        print(f"[warn] failed to load {path}: {e}. Starting fresh.")
        return {}

def atomic_pickle_dump(obj: dict, path: str) -> None:
    import os, pickle
    tmp = path + ".tmp"
    with open(tmp, "wb") as f:
        pickle.dump(obj, f, protocol=pickle.HIGHEST_PROTOCOL)
        f.flush(); os.fsync(f.fileno())
    os.replace(tmp, path)  # atomic replace

# %%
# Cell 5 — Shard + CSV helpers (per-batch pickles)
from pathlib import Path
import glob

SHARD_DIR = Path("Graph_data")
SHARD_DIR.mkdir(exist_ok=True)
DONE_CSV = SHARD_DIR / "done_ids.csv"

def list_shards() -> list[Path]:
    return sorted(SHARD_DIR.glob("shard_*.pkl"))

def load_shard_keys(p: Path) -> set[int]:
    with open(p, "rb") as f:
        d = pickle.load(f)
    return set(d.keys())

def load_done_ids() -> set[int]:
    # Prefer CSV for speed; fallback to scanning shards once
    if DONE_CSV.exists():
        s: set[int] = set()
        with open(DONE_CSV, "r") as f:
            for line in f:
                line = line.strip()
                if line.isdigit():
                    s.add(int(line))
        return s
    done: set[int] = set()
    for p in list_shards():
        try:
            done |= load_shard_keys(p)
        except Exception as e:
            print(f"[warn] skipping shard {p.name}: {e}")
    if done:
        with open(DONE_CSV, "w") as f:
            for aid in sorted(done):
                f.write(f"{aid}\n")
    return done

def append_done_ids(ids: list[int]) -> None:
    if not ids: return
    with open(DONE_CSV, "a") as f:
        for aid in ids:
            f.write(f"{aid}\n")

def atomic_dump(obj: dict, path: Path) -> None:
    tmp = path.with_suffix(path.suffix + ".tmp")
    with open(tmp, "wb") as f:
        pickle.dump(obj, f, protocol=pickle.HIGHEST_PROTOCOL)
        f.flush(); os.fsync(f.fileno())
    os.replace(tmp, path)

# %%
# Cell 6
# Batch/parallel
BATCH_SIZE = 25000 
MAX_WORKERS = 10 
MAX_RETRIES = 2 
RETRY_DELAY = 5

# %%
# Cell 7 — Load dataset & prepare pending IDs (bottom-up, sharded)
from datetime import datetime

df_deptos = pd.read_csv('Datasets/dataset_final.csv')
done_ids = load_done_ids()
print(f"Resume: {len(done_ids)} apartments already done (from shards/CSV).")

apt_ids = df_deptos['id'].tolist()[::-1]  # bottom-up
pending_ids = [i for i in apt_ids if i not in done_ids]

# Batch window
BATCH_SIZE = min(BATCH_SIZE, len(pending_ids))  # keep your earlier BATCH_SIZE variable
batch_ids = pending_ids[:BATCH_SIZE]
print(f"Processing {len(batch_ids)} apartments (remaining after this: {len(pending_ids) - len(batch_ids)})")

# Name this batch's shard file
if batch_ids:
    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    shard_name = f"shard_{ts}_{batch_ids[0]}-{batch_ids[-1]}.pkl"
    SHARD_PATH = SHARD_DIR / shard_name
    print(f"Shard file: {SHARD_PATH}")
else:
    SHARD_PATH = None
# Out:
# Resume: 215 apartments already done (from shards/CSV).
# Processing 25000 apartments (remaining after this: 0)
# Shard file: Graph_data\shard_20250829_184037_1556851659-1548097259.pkl

# %%
# Cell 8 — Worker + retry (Python 3.10+ typing)
def process_apartment_once(apt_id: int) -> tuple[int, dict[str, Data | None] | None, str | None]:
    """One attempt. Returns (apt_id, graphs_dict, error_str)."""
    try:
        driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
        try:
            with driver.session(database=DATABASE) as session:
                graphs: dict[str, Data | None] = {}
                for cls in CLASSES:
                    g = export_apartment_class_graph(apt_id, cls, session=session)
                    graphs[cls] = g  # may be None if no POIs
                return apt_id, graphs, None
        finally:
            driver.close()
    except (ServiceUnavailable, TransientError, Exception) as e:
        return apt_id, None, str(e)

def process_apartment_with_retries(apt_id: int) -> tuple[int, dict[str, Data | None] | None, str | None]:
    for attempt in range(1, MAX_RETRIES + 2):
        aid, graphs, err = process_apartment_once(apt_id)
        if err is None:
            return aid, graphs, None
        if attempt <= MAX_RETRIES:
            time.sleep(RETRY_DELAY)
    return aid, None, err  # final failure

# %%
# Cell 9 — Run threaded batch and save one shard + append done CSV
if not batch_ids:
    print("Nothing to do. You're up to date.")
else:
    start_batch = time.time()
    batch_graphs: dict[int, dict[str, Data | None]] = {}

    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as ex:
        futs = {ex.submit(process_apartment_with_retries, aid): aid for aid in batch_ids}
        for i, fut in enumerate(as_completed(futs), 1):
            aid = futs[fut]
            try:
                apt_id, graphs, err = fut.result()
            except Exception as e:
                apt_id, graphs, err = aid, None, f"worker crash: {e}"
            ok = (err is None and graphs is not None)
            status = "OK" if ok else f"ERR: {err}"
            print(f"[{i}/{len(batch_ids)}] apt={apt_id} -> {status}")
            if ok:
                batch_graphs[apt_id] = graphs

    # Save one pickle per batch (atomic) and append IDs to CSV
    if batch_graphs:
        atomic_dump(batch_graphs, SHARD_PATH)
        append_done_ids(sorted(batch_graphs.keys()))
# [24982/25000] apt=2788741066 -> OK
# [24983/25000] apt=1591393577 -> OK
# [24984/25000] apt=2794820112 -> OK
# [24985/25000] apt=2723323828 -> OK
# [24986/25000] apt=2824160304 -> OK
# [24987/25000] apt=1541765745 -> OK
# [24988/25000] apt=2800148714 -> OK
# [24989/25000] apt=2864600050 -> OK
# [24990/25000] apt=1571320205 -> OK
# [24991/25000] apt=1518864795 -> OK
# [24992/25000] apt=2849646914 -> OK
# [24993/25000] apt=1588684845 -> OK
# [24994/25000] apt=1521489447 -> OK
# [24995/25000] apt=1543740023 -> OK
# [24996/25000] apt=1536666991 -> OK
# [24997/25000] apt=2803401906 -> OK
# [24998/25000] apt=1592811585 -> OK
# [24999/25000] apt=2732119230 -> OK
# [25000/25000] apt=1548097259 -> OK
# Saved shard shard_20250829_184037_1556851659-1548097259.pkl with 25000 apartments.
# ✅ Batch finished in 22511.23s (ok: 25000, fail: 0)

# %%
# Cell 10 — Verify last N shards (quick summary)
N_SHARDS = 2  # inspect the last N shards
shards = list_shards()
print(f"Total shards: {len(shards)}")
for p in shards[-N_SHARDS:]:
    d = pickle.load(open(p, "rb"))
    print(f"\nShard {p.name}: {len(d)} apartments")
    # show first 2 apts from this shard
    for aid in list(d.keys())[:2]:
        graphs = d[aid]
        none_cnt = sum(1 for v in graphs.values() if v is None)
        print(f"  Apt {aid}: classes={len(graphs)}, none={none_cnt}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Cell 10 — Verify last N shards (quick summary)
#       2 N_SHARDS = 2  # inspect the last N shards
# ----> 3 shards = list_shards()
#       4 print(f"Total shards: {len(shards)}")
#       5 for p in shards[-N_SHARDS:]:
#
# NameError: name 'list_shards' is not defined

# %%
# Cell 11 — Verify last N apartments from the latest shard in Graph_data/
from pathlib import Path
import pickle
import torch

SHARD_DIR = Path("Graph_data")
N_LAST = 5  # change as needed

# Find newest shard by modification time
shards = sorted(SHARD_DIR.glob("shard_*.pkl"), key=lambda p: p.stat().st_mtime)
if not shards:
    print("No shard files found in Graph_data/.")
else:
    latest = shards[-1]
    print(f"Latest shard: {latest.name} (size: {latest.stat().st_size} bytes)")
    with open(latest, "rb") as f:
        d = pickle.load(f)  # dict[int -> dict[class -> Data|None]]

    print(f"Apartments in shard: {len(d)}")
    # Dict preserves insertion order (likely completion order). Take the last N.
    last_ids = list(d.keys())[-N_LAST:]
    print(f"\nInspecting last {len(last_ids)} apartments in this shard:\n")

    for aid in last_ids:
        graphs = d[aid]
        none_cnt = sum(1 for v in graphs.values() if v is None)
        print(f"Apartment {aid}: classes={len(graphs)}, none={none_cnt}")
        for cls in CLASSES:
            g = graphs.get(cls)
            if g is None:
                print(f"  - {cls:<24} -> None")
            else:
                print(f"  - {cls:<24} -> x={tuple(g.x.shape)}, edges={tuple(g.edge_index.shape)}, attr={tuple(g.edge_attr.shape)}")
        print()
# Out:
# Latest shard: shard_20250829_155254_1555433697-1584388845.pkl (size: 2320678 bytes)
# Apartments in shard: 100
#
# Inspecting last 5 apartments in this shard:
#
# Apartment 1551460201: classes=11, none=1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 28
#      26 none_cnt = sum(1 for v in graphs.values() if v is None)
#      27 print(f"Apartment {aid}: classes={len(graphs)}, none={none_cnt}")
# ---> 28 for cls in CLASSES:
#      29     g = graphs.get(cls)
#      30     if g is None:
#
# NameError: name 'CLASSES' is not defined

# %%
# tiny smoke test for 1 apt × 1 class
test_id = int(df_deptos['id'].iloc[0])
g = export_apartment_class_graph(test_id, 'medical')
print(g.edge_attr[:5].T)   # meters
print(g.edge_weight[:5].T) # normalized
# Out:
# tensor([[2341.9309, 2214.2764, 1610.3322, 1999.5028,  300.5760]])
# tensor([[0.0242, 0.0774, 0.3290, 0.1669, 0.4990]])

# %% [markdown]
# #### que los embeddings no le vayan a dar mas importancia a por ejemplo sports and leisure por el mero hecho de haber mas

# %%
# Sanity-check POI shards contain RAW METERS and (optionally) normalized weights.
# Works on Python 3.9+ and your saved torch_geometric Data objects.

import pickle, math
from pathlib import Path
import numpy as np
import torch

SHARD_DIR = Path("Graph_data")
SHARD_NAMES = [
    "shard_20250829_155254_1555433697-1584388845.pkl",
    "shard_20250829_183814_2862820058-1535195651.pkl",
    "shard_20250829_184037_1556851659-1548097259.pkl",
]

# How many apartments to sample per shard for detailed printouts
SAMPLE_APTS_PER_SHARD = 3

def as_numpy_1d(t):
    """Safely flatten a torch tensor to 1D numpy array."""
    if t is None:
        return None
    if isinstance(t, torch.Tensor):
        return t.view(-1).detach().cpu().numpy()
    return None

def describe(arr):
    if arr is None or arr.size == 0:
        return "n=0"
    return f"n={arr.size}, min={arr.min():.2f}, mean={arr.mean():.2f}, max={arr.max():.2f}"

def warn_if_weird_meters(arr):
    if arr is None or arr.size == 0:
        return "   - no edges"
    msg = []
    # Values should be meters (typically tens to a few thousand)
    if (arr < 1).mean() > 0.8:
        msg.append("⚠ many distances < 1m (not meters?)")
    if (arr > 10000).mean() > 0.1:
        msg.append("⚠ many distances > 10km (likely too large)")
    return "   - " + ("; ".join(msg) if msg else "looks like meters")

def corr_meters_vs_weight(meters, weight):
    if meters is None or weight is None or meters.size == 0 or weight.size == 0:
        return None
    m = meters
    w = weight
    if len(m) != len(w):
        return None
    # correlation should generally be negative (farther → smaller weight)
    c = np.corrcoef(m, w)[0,1]
    return float(c)

for shard_name in SHARD_NAMES:
    p = SHARD_DIR / shard_name
    if not p.exists():
        print(f"❌ Shard missing: {p}")
        continue
    print(f"\n=== Checking shard: {p.name}  (size {p.stat().st_size} bytes) ===")
    with open(p, "rb") as f:
        data = pickle.load(f)  # dict[int -> dict[class -> Data|None]]

    print(f"Apartments in shard: {len(data)}")

    # Aggregate stats
    total_edges = 0
    class_counts = {}
    meters_glob = []
    weight_glob = []

    # Sample a few apartments for detailed inspection
    sampled_ids = list(data.keys())[-SAMPLE_APTS_PER_SHARD:]

    for aid, gdict in data.items():
        if not isinstance(gdict, dict):
            # Old format (unlikely here)
            continue
        for cls, g in gdict.items():
            class_counts[cls] = class_counts.get(cls, 0) + 1
            if g is None:
                continue

            # Prefer edge_attr_meters if present, else edge_attr
            meters = None
            if hasattr(g, "edge_attr_meters"):
                meters = as_numpy_1d(getattr(g, "edge_attr_meters"))
            elif hasattr(g, "edge_attr"):
                meters = as_numpy_1d(getattr(g, "edge_attr"))
            weight = as_numpy_1d(getattr(g, "edge_weight", None))

            if meters is not None:
                meters_glob.append(meters)
                total_edges += meters.size
            if weight is not None:
                weight_glob.append(weight)

    print(f"Total edges across graphs (approx): {total_edges}")
    print("Per-class graph entries (including None):")
    for cls in sorted(class_counts):
        print(f"  - {cls:24} : {class_counts[cls]}")

    # Global meter/weight sanity (flattened)
    if meters_glob:
        M = np.concatenate(meters_glob)
        print(f"Raw distances (meters) global: {describe(M)}")
        print(" ", warn_if_weird_meters(M))
    else:
        print("⚠ No raw-distance arrays found (edge_attr/edge_attr_meters missing?)")

    if weight_glob:
        W = np.concatenate(weight_glob)
        print(f"Normalized weights global: {describe(W)}")
        print(f"   - fraction in (0,1]: {((W>0)&(W<=1)).mean():.3f}")
    else:
        print("ℹ No normalized weights found (edge_weight absent) — ok if you didn’t save them.")

    # Detailed sample:
    print("\n--- Detailed sample (last few apartments in this shard) ---")
    for aid in sampled_ids:
        gdict = data[aid]
        print(f"\nApartment {aid}:")
        for cls, g in gdict.items():
            if g is None:
                print(f"  * {cls:<24} -> None")
                continue
            if hasattr(g, "edge_attr_meters"):
                meters = as_numpy_1d(g.edge_attr_meters)
                src = "edge_attr_meters"
            else:
                meters = as_numpy_1d(g.edge_attr)
                src = "edge_attr"
            weight = as_numpy_1d(getattr(g, "edge_weight", None))

            print(f"  * {cls:<24} -> edges={0 if meters is None else meters.size}")
            if meters is not None and meters.size:
                print(f"      meters [{src}] : {describe(meters)}")
                print(       warn_if_weird_meters(meters))
            if weight is not None and weight.size:
                print(f"      weights       : {describe(weight)}")
                corr = corr_meters_vs_weight(meters, weight)
                if corr is not None and not math.isnan(corr):
                    print(f"      corr(meters, weight) ≈ {corr:.3f} (expect negative)")
# Out:
# === Checking shard: shard_20250829_155254_1555433697-1584388845.pkl  (size 2320678 bytes) ===
# Apartments in shard: 100
# Total edges across graphs (approx): 25748
# Per-class graph entries (including None):
#   - arts_and_entertainment   : 100
#   - education_prim           : 100
#   - education_sup            : 100
#   - food_and_drink           : 100
#   - food_and_drink_stores    : 100
#   - medical                  : 100
#   - park_like                : 100
#   - religion                 : 100
#   - security                 : 100
#   - sport_and_leisure        : 100
#   - veterinary               : 100
# Raw distances (meters) global: n=25748, min=1.00, mean=1007.22, max=2399.94
#      - looks like meters
# Normalized weights global: n=25748, min=0.00, mean=0.35, max=1.00
#    - fraction in (0,1]: 1.000
#
# --- Detailed sample (last few apartments in this shard) ---
#
# Apartment 1577371843:
#   * sport_and_leisure        -> edges=23
#       meters [edge_attr] : n=23, min=285.55, mean=601.35, max=2396.07
#    - looks like meters
#       weights       : n=23, min=0.00, mean=0.39, max=0.85
#       corr(meters, weight) ≈ -0.449 (expect negative)
#   * medical                  -> edges=13
#       meters [edge_attr] : n=13, min=158.23, mean=834.15, max=1853.86
#    - looks like meters
#       weights       : n=13, min=0.23, mean=0.49, max=0.85
#       corr(meters, weight) ≈ -0.459 (expect negative)
#   * education_prim           -> None
#   * veterinary               -> edges=2
#       meters [edge_attr] : n=2, min=345.69, mean=682.79, max=1019.89
#    - looks like meters
#       weights       : n=2, min=0.15, mean=0.43, max=0.71
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * food_and_drink_stores    -> edges=11
#       meters [edge_attr] : n=11, min=275.35, mean=492.44, max=1189.77
#    - looks like meters
#       weights       : n=11, min=0.01, mean=0.38, max=0.75
#       corr(meters, weight) ≈ -0.868 (expect negative)
#   * arts_and_entertainment   -> edges=6
#       meters [edge_attr] : n=6, min=999.97, mean=1510.77, max=2149.88
#    - looks like meters
#       weights       : n=6, min=0.10, mean=0.37, max=0.58
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * food_and_drink           -> edges=16
#       meters [edge_attr] : n=16, min=302.95, mean=403.96, max=975.41
#    - looks like meters
#       weights       : n=16, min=0.19, mean=0.38, max=0.50
#       corr(meters, weight) ≈ -0.750 (expect negative)
#   * park_like                -> edges=2
#       meters [edge_attr] : n=2, min=340.48, mean=364.28, max=388.08
#    - looks like meters
#       weights       : n=2, min=0.35, mean=0.39, max=0.43
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * security                 -> edges=3
#       meters [edge_attr] : n=3, min=1808.13, mean=1833.74, max=1870.86
#    - looks like meters
#       weights       : n=3, min=0.22, mean=0.24, max=0.25
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * religion                 -> None
#   * education_sup            -> edges=3
#       meters [edge_attr] : n=3, min=233.08, mean=787.15, max=1381.05
#    - looks like meters
#       weights       : n=3, min=0.42, mean=0.67, max=0.90
#       corr(meters, weight) ≈ -1.000 (expect negative)
#
# Apartment 1587986915:
#   * sport_and_leisure        -> edges=26
#       meters [edge_attr] : n=26, min=93.03, mean=688.63, max=1052.24
#    - looks like meters
#       weights       : n=26, min=0.12, mean=0.41, max=0.92
#       corr(meters, weight) ≈ -0.941 (expect negative)
#   * medical                  -> edges=51
#       meters [edge_attr] : n=51, min=374.65, mean=1345.73, max=2336.57
#    - looks like meters
#       weights       : n=51, min=0.03, mean=0.35, max=0.84
#       corr(meters, weight) ≈ -0.663 (expect negative)
#   * education_prim           -> edges=20
#       meters [edge_attr] : n=20, min=153.36, mean=394.97, max=586.75
#    - looks like meters
#       weights       : n=20, min=0.02, mean=0.34, max=0.74
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * veterinary               -> edges=6
#       meters [edge_attr] : n=6, min=124.25, mean=628.23, max=880.56
#    - looks like meters
#       weights       : n=6, min=0.27, mean=0.48, max=0.90
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * food_and_drink_stores    -> edges=71
#       meters [edge_attr] : n=71, min=32.45, mean=526.67, max=1187.93
#    - looks like meters
#       weights       : n=71, min=0.00, mean=0.33, max=0.95
#       corr(meters, weight) ≈ -0.660 (expect negative)
#   * arts_and_entertainment   -> edges=118
#       meters [edge_attr] : n=118, min=473.91, mean=1501.37, max=2354.87
#    - looks like meters
#       weights       : n=118, min=0.02, mean=0.33, max=0.80
#       corr(meters, weight) ≈ -0.794 (expect negative)
#   * food_and_drink           -> edges=60
#       meters [edge_attr] : n=60, min=125.67, mean=460.40, max=1198.96
#    - looks like meters
#       weights       : n=60, min=0.00, mean=0.34, max=0.79
#       corr(meters, weight) ≈ -0.777 (expect negative)
#   * park_like                -> edges=11
#       meters [edge_attr] : n=11, min=138.86, mean=325.63, max=512.48
#    - looks like meters
#       weights       : n=11, min=0.15, mean=0.46, max=0.77
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * security                 -> edges=22
#       meters [edge_attr] : n=22, min=122.88, mean=1437.42, max=2369.65
#    - looks like meters
#       weights       : n=22, min=0.01, mean=0.40, max=0.95
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * religion                 -> edges=12
#       meters [edge_attr] : n=12, min=240.18, mean=548.51, max=1124.60
#    - looks like meters
#       weights       : n=12, min=0.00, mean=0.28, max=0.60
#       corr(meters, weight) ≈ -0.627 (expect negative)
#   * education_sup            -> edges=247
#       meters [edge_attr] : n=247, min=209.13, mean=1708.72, max=2398.68
#    - looks like meters
#       weights       : n=247, min=0.00, mean=0.29, max=0.91
#       corr(meters, weight) ≈ -1.000 (expect negative)
#
# Apartment 1584388845:
#   * sport_and_leisure        -> edges=103
#       meters [edge_attr] : n=103, min=38.32, mean=961.47, max=2391.00
#    - looks like meters
#       weights       : n=103, min=0.00, mean=0.22, max=0.97
#       corr(meters, weight) ≈ -0.803 (expect negative)
#   * medical                  -> edges=68
#       meters [edge_attr] : n=68, min=85.22, mean=876.13, max=2303.82
#    - looks like meters
#       weights       : n=68, min=0.03, mean=0.46, max=0.86
#       corr(meters, weight) ≈ -0.591 (expect negative)
#   * education_prim           -> edges=5
#       meters [edge_attr] : n=5, min=278.70, mean=380.82, max=568.29
#    - looks like meters
#       weights       : n=5, min=0.05, mean=0.37, max=0.54
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * veterinary               -> edges=5
#       meters [edge_attr] : n=5, min=605.05, mean=911.02, max=1130.22
#    - looks like meters
#       weights       : n=5, min=0.06, mean=0.24, max=0.50
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * food_and_drink_stores    -> edges=58
#       meters [edge_attr] : n=58, min=74.56, mean=388.52, max=1124.82
#    - looks like meters
#       weights       : n=58, min=0.01, mean=0.44, max=0.88
#       corr(meters, weight) ≈ -0.781 (expect negative)
#   * arts_and_entertainment   -> edges=36
#       meters [edge_attr] : n=36, min=226.24, mean=1542.82, max=2331.34
#    - looks like meters
#       weights       : n=36, min=0.03, mean=0.31, max=0.86
#       corr(meters, weight) ≈ -0.870 (expect negative)
#   * food_and_drink           -> edges=185
#       meters [edge_attr] : n=185, min=46.45, mean=374.05, max=598.39
#    - looks like meters
#       weights       : n=185, min=0.00, mean=0.38, max=0.92
#       corr(meters, weight) ≈ -0.979 (expect negative)
#   * park_like                -> edges=5
#       meters [edge_attr] : n=5, min=215.81, mean=384.07, max=537.40
#    - looks like meters
#       weights       : n=5, min=0.10, mean=0.36, max=0.64
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * security                 -> edges=4
#       meters [edge_attr] : n=4, min=531.75, mean=1698.59, max=2327.41
#    - looks like meters
#       weights       : n=4, min=0.03, mean=0.29, max=0.78
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * religion                 -> edges=5
#       meters [edge_attr] : n=5, min=126.69, mean=310.52, max=465.01
#    - looks like meters
#       weights       : n=5, min=0.22, mean=0.48, max=0.79
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * education_sup            -> edges=63
#       meters [edge_attr] : n=63, min=159.46, mean=1286.14, max=2267.63
#    - looks like meters
#       weights       : n=63, min=0.06, mean=0.46, max=0.93
#       corr(meters, weight) ≈ -1.000 (expect negative)
#
# === Checking shard: shard_20250829_183814_2862820058-1535195651.pkl  (size 2664090 bytes) ===
# Apartments in shard: 115
# Total edges across graphs (approx): 29526
# Per-class graph entries (including None):
#   - arts_and_entertainment   : 115
#   - education_prim           : 115
#   - education_sup            : 115
#   - food_and_drink           : 115
#   - food_and_drink_stores    : 115
#   - medical                  : 115
#   - park_like                : 115
#   - religion                 : 115
#   - security                 : 115
#   - sport_and_leisure        : 115
#   - veterinary               : 115
# Raw distances (meters) global: n=29526, min=1.45, mean=1017.32, max=2399.96
#      - looks like meters
# Normalized weights global: n=29526, min=0.00, mean=0.36, max=1.00
#    - fraction in (0,1]: 1.000
#
# --- Detailed sample (last few apartments in this shard) ---
#
# Apartment 1585447915:
#   * sport_and_leisure        -> edges=43
#       meters [edge_attr] : n=43, min=86.44, mean=829.41, max=1177.27
#    - looks like meters
#       weights       : n=43, min=0.02, mean=0.31, max=0.93
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * medical                  -> edges=107
#       meters [edge_attr] : n=107, min=36.11, mean=884.58, max=2392.99
#    - looks like meters
#       weights       : n=107, min=0.00, mean=0.45, max=0.94
#       corr(meters, weight) ≈ -0.693 (expect negative)
#   * education_prim           -> edges=14
#       meters [edge_attr] : n=14, min=124.24, mean=385.58, max=579.45
#    - looks like meters
#       weights       : n=14, min=0.03, mean=0.36, max=0.79
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * veterinary               -> edges=1
#       meters [edge_attr] : n=1, min=1123.77, mean=1123.77, max=1123.77
#    - looks like meters
#       weights       : n=1, min=0.06, mean=0.06, max=0.06
#   * food_and_drink_stores    -> edges=53
#       meters [edge_attr] : n=53, min=71.71, mean=389.93, max=958.43
#    - looks like meters
#       weights       : n=53, min=0.00, mean=0.43, max=0.94
#       corr(meters, weight) ≈ -0.793 (expect negative)
#   * arts_and_entertainment   -> edges=75
#       meters [edge_attr] : n=75, min=186.74, mean=1540.93, max=2385.53
#    - looks like meters
#       weights       : n=75, min=0.01, mean=0.33, max=0.92
#       corr(meters, weight) ≈ -0.935 (expect negative)
#   * food_and_drink           -> edges=166
#       meters [edge_attr] : n=166, min=38.12, mean=328.78, max=639.12
#    - looks like meters
#       weights       : n=166, min=0.00, mean=0.46, max=0.94
#       corr(meters, weight) ≈ -0.966 (expect negative)
#   * park_like                -> edges=6
#       meters [edge_attr] : n=6, min=175.31, mean=356.14, max=498.77
#    - looks like meters
#       weights       : n=6, min=0.17, mean=0.41, max=0.71
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * security                 -> edges=7
#       meters [edge_attr] : n=7, min=237.67, mean=1531.36, max=2322.48
#    - looks like meters
#       weights       : n=7, min=0.03, mean=0.36, max=0.90
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * religion                 -> edges=5
#       meters [edge_attr] : n=5, min=211.04, mean=372.72, max=558.30
#    - looks like meters
#       weights       : n=5, min=0.07, mean=0.38, max=0.65
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * education_sup            -> edges=148
#       meters [edge_attr] : n=148, min=260.81, mean=1531.49, max=2350.60
#    - looks like meters
#       weights       : n=148, min=0.02, mean=0.36, max=0.89
#       corr(meters, weight) ≈ -1.000 (expect negative)
#
# Apartment 1535195651:
#   * sport_and_leisure        -> edges=14
#       meters [edge_attr] : n=14, min=278.64, mean=739.75, max=1175.47
#    - looks like meters
#       weights       : n=14, min=0.02, mean=0.33, max=0.77
#       corr(meters, weight) ≈ -0.931 (expect negative)
#   * medical                  -> edges=8
#       meters [edge_attr] : n=8, min=423.16, mean=1103.65, max=2270.30
#    - looks like meters
#       weights       : n=8, min=0.05, mean=0.35, max=0.82
#       corr(meters, weight) ≈ -0.463 (expect negative)
#   * education_prim           -> edges=10
#       meters [edge_attr] : n=10, min=341.54, mean=490.83, max=596.14
#    - looks like meters
#       weights       : n=10, min=0.01, mean=0.18, max=0.43
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * veterinary               -> edges=1
#       meters [edge_attr] : n=1, min=564.38, mean=564.38, max=564.38
#    - looks like meters
#       weights       : n=1, min=0.53, mean=0.53, max=0.53
#   * food_and_drink_stores    -> edges=6
#       meters [edge_attr] : n=6, min=476.49, mean=577.96, max=757.77
#    - looks like meters
#       weights       : n=6, min=0.02, mean=0.30, max=0.59
#       corr(meters, weight) ≈ 0.146 (expect negative)
#   * arts_and_entertainment   -> edges=8
#       meters [edge_attr] : n=8, min=197.41, mean=1220.76, max=2357.00
#    - looks like meters
#       weights       : n=8, min=0.02, mean=0.48, max=0.84
#       corr(meters, weight) ≈ -0.997 (expect negative)
#   * food_and_drink           -> edges=5
#       meters [edge_attr] : n=5, min=479.56, mean=550.65, max=759.79
#    - looks like meters
#       weights       : n=5, min=0.13, mean=0.21, max=0.37
#       corr(meters, weight) ≈ 0.914 (expect negative)
#   * park_like                -> edges=2
#       meters [edge_attr] : n=2, min=26.83, mean=204.55, max=382.28
#    - looks like meters
#       weights       : n=2, min=0.36, mean=0.66, max=0.96
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * security                 -> edges=9
#       meters [edge_attr] : n=9, min=1054.06, mean=1575.81, max=2099.75
#    - looks like meters
#       weights       : n=9, min=0.13, mean=0.34, max=0.56
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * religion                 -> None
#   * education_sup            -> edges=36
#       meters [edge_attr] : n=36, min=274.29, mean=1234.19, max=1885.43
#    - looks like meters
#       weights       : n=36, min=0.21, mean=0.49, max=0.89
#       corr(meters, weight) ≈ -1.000 (expect negative)
#
# Apartment 1581230581:
#   * sport_and_leisure        -> edges=38
#       meters [edge_attr] : n=38, min=35.14, mean=746.60, max=1126.71
#    - looks like meters
#       weights       : n=38, min=0.06, mean=0.38, max=0.97
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * medical                  -> edges=46
#       meters [edge_attr] : n=46, min=148.85, mean=1326.39, max=2370.44
#    - looks like meters
#       weights       : n=46, min=0.01, mean=0.35, max=0.75
#       corr(meters, weight) ≈ -0.739 (expect negative)
#   * education_prim           -> edges=18
#       meters [edge_attr] : n=18, min=168.90, mean=345.66, max=558.83
#    - looks like meters
#       weights       : n=18, min=0.07, mean=0.42, max=0.72
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * veterinary               -> edges=3
#       meters [edge_attr] : n=3, min=994.96, mean=1041.26, max=1126.33
#    - looks like meters
#       weights       : n=3, min=0.06, mean=0.13, max=0.17
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * food_and_drink_stores    -> edges=28
#       meters [edge_attr] : n=28, min=161.91, mean=538.89, max=1170.56
#    - looks like meters
#       weights       : n=28, min=0.02, mean=0.37, max=0.75
#       corr(meters, weight) ≈ -0.662 (expect negative)
#   * arts_and_entertainment   -> edges=55
#       meters [edge_attr] : n=55, min=602.23, mean=1839.91, max=2389.34
#    - looks like meters
#       weights       : n=55, min=0.00, mean=0.23, max=0.75
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * food_and_drink           -> edges=62
#       meters [edge_attr] : n=62, min=138.09, mean=401.36, max=743.04
#    - looks like meters
#       weights       : n=62, min=0.01, mean=0.34, max=0.77
#       corr(meters, weight) ≈ -0.932 (expect negative)
#   * park_like                -> edges=8
#       meters [edge_attr] : n=8, min=132.93, mean=284.76, max=594.28
#    - looks like meters
#       weights       : n=8, min=0.01, mean=0.53, max=0.78
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * security                 -> edges=17
#       meters [edge_attr] : n=17, min=944.99, mean=1811.72, max=2381.13
#    - looks like meters
#       weights       : n=17, min=0.01, mean=0.25, max=0.61
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * religion                 -> edges=7
#       meters [edge_attr] : n=7, min=215.46, mean=615.51, max=1187.93
#    - looks like meters
#       weights       : n=7, min=0.01, mean=0.22, max=0.64
#       corr(meters, weight) ≈ -0.641 (expect negative)
#   * education_sup            -> edges=110
#       meters [edge_attr] : n=110, min=366.95, mean=1537.23, max=2385.79
#    - looks like meters
#       weights       : n=110, min=0.01, mean=0.36, max=0.85
#       corr(meters, weight) ≈ -1.000 (expect negative)
#
# === Checking shard: shard_20250829_184037_1556851659-1548097259.pkl  (size 637580813 bytes) ===
# c:\Users\Pc-ADS\.conda\envs\tf\lib\site-packages\numpy\lib\function_base.py:2889: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# c:\Users\Pc-ADS\.conda\envs\tf\lib\site-packages\numpy\lib\function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# c:\Users\Pc-ADS\.conda\envs\tf\lib\site-packages\numpy\lib\function_base.py:2748: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# Apartments in shard: 25000
# Total edges across graphs (approx): 7778481
# Per-class graph entries (including None):
#   - arts_and_entertainment   : 25000
#   - education_prim           : 25000
#   - education_sup            : 25000
#   - food_and_drink           : 25000
#   - food_and_drink_stores    : 25000
#   - medical                  : 25000
#   - park_like                : 25000
#   - religion                 : 25000
#   - security                 : 25000
#   - sport_and_leisure        : 25000
#   - veterinary               : 25000
# Raw distances (meters) global: n=7778481, min=0.00, mean=1059.62, max=2400.00
#      - looks like meters
# Normalized weights global: n=7778481, min=0.00, mean=0.35, max=1.00
#    - fraction in (0,1]: 1.000
#
# --- Detailed sample (last few apartments in this shard) ---
#
# Apartment 1592811585:
#   * sport_and_leisure        -> edges=93
#       meters [edge_attr] : n=93, min=224.56, mean=765.53, max=2291.59
#    - looks like meters
#       weights       : n=93, min=0.01, mean=0.24, max=0.81
#       corr(meters, weight) ≈ -0.487 (expect negative)
#   * medical                  -> edges=35
#       meters [edge_attr] : n=35, min=324.30, mean=1242.93, max=2381.80
#    - looks like meters
#       weights       : n=35, min=0.01, mean=0.40, max=0.86
#       corr(meters, weight) ≈ -0.718 (expect negative)
#   * education_prim           -> edges=6
#       meters [edge_attr] : n=6, min=227.19, mean=372.77, max=568.48
#    - looks like meters
#       weights       : n=6, min=0.05, mean=0.38, max=0.62
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * veterinary               -> edges=1
#       meters [edge_attr] : n=1, min=387.72, mean=387.72, max=387.72
#    - looks like meters
#       weights       : n=1, min=0.68, mean=0.68, max=0.68
#   * food_and_drink_stores    -> edges=12
#       meters [edge_attr] : n=12, min=274.67, mean=554.84, max=1035.31
#    - looks like meters
#       weights       : n=12, min=0.04, mean=0.30, max=0.75
#       corr(meters, weight) ≈ -0.617 (expect negative)
#   * arts_and_entertainment   -> edges=25
#       meters [edge_attr] : n=25, min=153.71, mean=1477.50, max=2259.75
#    - looks like meters
#       weights       : n=25, min=0.06, mean=0.34, max=0.94
#       corr(meters, weight) ≈ -0.937 (expect negative)
#   * food_and_drink           -> edges=47
#       meters [edge_attr] : n=47, min=142.83, mean=463.94, max=597.56
#    - looks like meters
#       weights       : n=47, min=0.00, mean=0.25, max=0.76
#       corr(meters, weight) ≈ -0.889 (expect negative)
#   * park_like                -> edges=3
#       meters [edge_attr] : n=3, min=274.12, mean=432.34, max=555.81
#    - looks like meters
#       weights       : n=3, min=0.07, mean=0.28, max=0.54
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * security                 -> edges=7
#       meters [edge_attr] : n=7, min=1322.36, mean=1828.16, max=2395.38
#    - looks like meters
#       weights       : n=7, min=0.00, mean=0.24, max=0.45
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * religion                 -> edges=2
#       meters [edge_attr] : n=2, min=142.11, mean=325.19, max=508.27
#    - looks like meters
#       weights       : n=2, min=0.15, mean=0.46, max=0.76
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * education_sup            -> edges=9
#       meters [edge_attr] : n=9, min=631.45, mean=1753.94, max=2359.96
#    - looks like meters
#       weights       : n=9, min=0.02, mean=0.27, max=0.74
#       corr(meters, weight) ≈ -1.000 (expect negative)
#
# Apartment 2732119230:
#   * sport_and_leisure        -> edges=99
#       meters [edge_attr] : n=99, min=264.12, mean=731.84, max=2362.44
#    - looks like meters
#       weights       : n=99, min=0.00, mean=0.34, max=0.78
#       corr(meters, weight) ≈ -0.684 (expect negative)
#   * medical                  -> edges=31
#       meters [edge_attr] : n=31, min=119.43, mean=1119.55, max=2336.40
#    - looks like meters
#       weights       : n=31, min=0.01, mean=0.42, max=0.93
#       corr(meters, weight) ≈ -0.711 (expect negative)
#   * education_prim           -> edges=8
#       meters [edge_attr] : n=8, min=200.48, mean=428.49, max=552.64
#    - looks like meters
#       weights       : n=8, min=0.08, mean=0.29, max=0.67
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * veterinary               -> edges=1
#       meters [edge_attr] : n=1, min=761.53, mean=761.53, max=761.53
#    - looks like meters
#       weights       : n=1, min=0.37, mean=0.37, max=0.37
#   * food_and_drink_stores    -> edges=10
#       meters [edge_attr] : n=10, min=150.35, mean=491.62, max=957.96
#    - looks like meters
#       weights       : n=10, min=0.20, mean=0.41, max=0.75
#       corr(meters, weight) ≈ -0.793 (expect negative)
#   * arts_and_entertainment   -> edges=24
#       meters [edge_attr] : n=24, min=284.38, mean=1546.27, max=2382.12
#    - looks like meters
#       weights       : n=24, min=0.01, mean=0.33, max=0.76
#       corr(meters, weight) ≈ -0.980 (expect negative)
#   * food_and_drink           -> edges=24
#       meters [edge_attr] : n=24, min=109.64, mean=340.82, max=964.03
#    - looks like meters
#       weights       : n=24, min=0.04, mean=0.47, max=0.88
#       corr(meters, weight) ≈ -0.851 (expect negative)
#   * park_like                -> edges=3
#       meters [edge_attr] : n=3, min=251.01, mean=441.75, max=567.75
#    - looks like meters
#       weights       : n=3, min=0.05, mean=0.26, max=0.58
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * security                 -> edges=7
#       meters [edge_attr] : n=7, min=1559.47, mean=2130.91, max=2378.99
#    - looks like meters
#       weights       : n=7, min=0.01, mean=0.11, max=0.35
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * religion                 -> edges=1
#       meters [edge_attr] : n=1, min=297.74, mean=297.74, max=297.74
#    - looks like meters
#       weights       : n=1, min=0.50, mean=0.50, max=0.50
#   * education_sup            -> edges=7
#       meters [edge_attr] : n=7, min=979.77, mean=1511.27, max=1833.05
#    - looks like meters
#       weights       : n=7, min=0.24, mean=0.37, max=0.59
#       corr(meters, weight) ≈ -1.000 (expect negative)
#
# Apartment 1548097259:
#   * sport_and_leisure        -> edges=89
#       meters [edge_attr] : n=89, min=124.71, mean=658.20, max=2167.41
#    - looks like meters
#       weights       : n=89, min=0.00, mean=0.41, max=0.81
#       corr(meters, weight) ≈ -0.842 (expect negative)
#   * medical                  -> edges=31
#       meters [edge_attr] : n=31, min=226.58, mean=1154.35, max=2346.32
#    - looks like meters
#       weights       : n=31, min=0.02, mean=0.42, max=0.88
#       corr(meters, weight) ≈ -0.772 (expect negative)
#   * education_prim           -> edges=8
#       meters [edge_attr] : n=8, min=389.30, mean=486.41, max=591.12
#    - looks like meters
#       weights       : n=8, min=0.01, mean=0.19, max=0.35
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * veterinary               -> edges=1
#       meters [edge_attr] : n=1, min=579.37, mean=579.37, max=579.37
#    - looks like meters
#       weights       : n=1, min=0.52, mean=0.52, max=0.52
#   * food_and_drink_stores    -> edges=12
#       meters [edge_attr] : n=12, min=26.10, mean=528.01, max=1128.51
#    - looks like meters
#       weights       : n=12, min=0.06, mean=0.38, max=0.96
#       corr(meters, weight) ≈ -0.802 (expect negative)
#   * arts_and_entertainment   -> edges=25
#       meters [edge_attr] : n=25, min=255.53, mean=1581.81, max=2306.14
#    - looks like meters
#       weights       : n=25, min=0.04, mean=0.30, max=0.79
#       corr(meters, weight) ≈ -0.921 (expect negative)
#   * food_and_drink           -> edges=25
#       meters [edge_attr] : n=25, min=172.73, mean=419.65, max=979.30
#    - looks like meters
#       weights       : n=25, min=0.02, mean=0.34, max=0.83
#       corr(meters, weight) ≈ -0.821 (expect negative)
#   * park_like                -> edges=6
#       meters [edge_attr] : n=6, min=265.39, mean=493.32, max=599.63
#    - looks like meters
#       weights       : n=6, min=0.00, mean=0.18, max=0.56
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * security                 -> edges=7
#       meters [edge_attr] : n=7, min=1354.31, mean=1969.09, max=2176.97
#    - looks like meters
#       weights       : n=7, min=0.09, mean=0.18, max=0.44
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * religion                 -> edges=3
#       meters [edge_attr] : n=3, min=455.24, mean=504.32, max=580.14
#    - looks like meters
#       weights       : n=3, min=0.03, mean=0.16, max=0.24
#       corr(meters, weight) ≈ -1.000 (expect negative)
#   * education_sup            -> edges=7
#       meters [edge_attr] : n=7, min=781.50, mean=1452.85, max=1818.74
#    - looks like meters
#       weights       : n=7, min=0.24, mean=0.39, max=0.67
#       corr(meters, weight) ≈ -1.000 (expect negative)
