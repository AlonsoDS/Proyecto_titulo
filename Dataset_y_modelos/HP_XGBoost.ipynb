# %%
import time
import re
from typing import Dict, Tuple, Optional
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score
import xgboost as xgb
from xgboost import XGBRegressor
from xgboost.callback import EarlyStopping

import optuna
from optuna.samplers import TPESampler
from optuna.pruners import MedianPruner

# %%
# Configuración
RANDOM_STATE = 42
TEST_SIZE = 0.2
VAL_SIZE = 0.2 # Porcion del set train

N_TRIALS_XGB = 60
EARLY_STOP_ROUNDS = 200

# %% [markdown]
# ### Hiperparametros para primer modelo XGBoost --> Control: Sin VCR ni coordenadas

# %%
# Configuración básica del dataset
df_vcr_c = pd.read_csv('dataset_vcr_compact.csv')
df_vcr_c = df_vcr_c[df_vcr_c['monto'] < 56000].copy()
df_vcr_c['log_monto']=np.log(df_vcr_c['monto'])
df_vcr_c['log_monto'].describe()
# Out:
# count    25211.000000
# mean         8.395828
# std          0.830310
# min          5.950643
# 25%          7.740664
# 50%          8.242756
# 75%          8.984694
# max         10.915088
# Name: log_monto, dtype: float64

# %%
#Configuración específica del dataset para el modelo
df_base =df_vcr_c.copy()
obj_cols = df_base.select_dtypes(include=["object"]).columns
cols_to_drop = list(obj_cols) + ["id", "latitud", "longitud"]
df_base = df_base.drop(columns=cols_to_drop)
df_base.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25211 entries, 0 to 25214
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   monto                 25211 non-null  int64
#  1   superficie_t          25211 non-null  float64
#  2   dormitorios           25211 non-null  int64
#  3   dormitorios_faltante  25211 non-null  int64
#  4   banos                 25211 non-null  int64
#  5   banos_faltante        25211 non-null  int64
#  6   antiguedad            25211 non-null  int64
#  7   antiguedad_faltante   25211 non-null  int64
#  8   Or_N                  25211 non-null  int64
#  9   Or_S                  25211 non-null  int64
#  10  Or_E                  25211 non-null  int64
#  11  Or_O                  25211 non-null  int64
#  12  Or_Faltante           25211 non-null  int64
#  13  terraza               25211 non-null  float64
#  14  estacionamiento       25211 non-null  int64
#  15  bodegas               25211 non-null  int64
#  16  flag_Departamento     25211 non-null  int64
#  17  flag_Multinivel       25211 non-null  int64
#  18  flag_Semipiso         25211 non-null  int64
#  19  flag_Premium          25211 non-null  int64
#  20  flag_Monoambiente     25211 non-null  int64
#  21  flag_Loft             25211 non-null  int64
#  22  log_monto             25211 non-null  float64
# dtypes: float64(3), int64(20)
# memory usage: 4.6 MB

# %%
# Split
DF = df_base
X = DF.drop(columns=["monto", "log_monto"]).copy()
y = DF["log_monto"].values

X_train_full, X_test, y_train_full, y_test = train_test_split(
X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE
)
X_train, X_val, y_train, y_val = train_test_split(
X_train_full, y_train_full, test_size=VAL_SIZE, random_state=RANDOM_STATE
)
print(f"Shapes -> train: {X_train.shape}, val: {X_val.shape}, test: {X_test.shape}")
# Out:
# Shapes -> train: (16134, 21), val: (4034, 21), test: (5043, 21)

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
dval   = xgb.DMatrix(X_val,   label=y_val)

# %%
def objective_xgb(trial):
    # Buscamos en NOMBRES estilo sklearn para que luego pasarlos directo al XGBRegressor
    params_skl = {
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.3, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 12),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "gamma": trial.suggest_float("gamma", 0.0, 5.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 1.0, log=True),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-2, 10.0, log=True),
    }
    num_boost_round = trial.suggest_int("num_boost_round", 800, 3000, step=100)

    # Mapear a nombres de xgb.train
    params_train = {
        "objective": "reg:squarederror",
        "eval_metric": "rmse",   # en LOG
        "device": "cuda",        # GPU obligatoria
        "seed": RANDOM_STATE,
        "eta": params_skl["learning_rate"],
        "max_depth": params_skl["max_depth"],
        "min_child_weight": params_skl["min_child_weight"],
        "subsample": params_skl["subsample"],
        "colsample_bytree": params_skl["colsample_bytree"],
        "gamma": params_skl["gamma"],
        "alpha": params_skl["reg_alpha"],
        "lambda": params_skl["reg_lambda"],
    }

    booster = xgb.train(
        params=params_train,
        dtrain=dtrain,
        num_boost_round=num_boost_round,
        evals=[(dval, "val")],
        early_stopping_rounds=EARLY_STOP_ROUNDS,
        verbose_eval=False,
    )

    y_val_pred_log = booster.predict(dval, iteration_range=(0, booster.best_iteration + 1))
    rmse_log_val = float(np.sqrt(np.mean((y_val - y_val_pred_log) ** 2)))
    # Guardar también n_estimators óptimo en los user_attrs del trial
    trial.set_user_attr("best_n_estimators", booster.best_iteration + 1)
    # Devolver params estilo sklearn (los leeremos después)
    for k, v in params_skl.items():
        trial.set_user_attr(k, v)
    return rmse_log_val

# %%
study = optuna.create_study(
    direction="minimize",
    sampler=TPESampler(seed=RANDOM_STATE),
    pruner=MedianPruner(n_startup_trials=5),
)
print("Optuna XGB: iniciando búsqueda...")
study.optimize(objective_xgb, n_trials=N_TRIALS_XGB, show_progress_bar=True)

t = study.best_trial
best_n_estimators = t.user_attrs["best_n_estimators"]
best_params_sklearn = {
    "n_estimators": best_n_estimators,
    "learning_rate": t.user_attrs["learning_rate"],
    "max_depth": t.user_attrs["max_depth"],
    "min_child_weight": t.user_attrs["min_child_weight"],
    "subsample": t.user_attrs["subsample"],
    "colsample_bytree": t.user_attrs["colsample_bytree"],
    "gamma": t.user_attrs["gamma"],
    "reg_alpha": t.user_attrs["reg_alpha"],
    "reg_lambda": t.user_attrs["reg_lambda"],
    "objective": "reg:squarederror",
    "random_state": RANDOM_STATE,
}
print("\nMejores HP XGB (val RMSE_log ↓):")
print({**best_params_sklearn})
# Out:
# [I 2025-10-08 17:03:50,932] A new study created in memory with name: no-name-9e470bad-8c01-43ef-a25a-a33a6aa1c489
# Optuna XGB: iniciando búsqueda...
#   0%|          | 0/60 [00:00<?, ?it/s]
# [I 2025-10-08 17:04:08,631] Trial 0 finished with value: 0.25438285482034523 and parameters: {'learning_rate': 0.008468008575248327, 'max_depth': 10, 'min_child_weight': 9, 'subsample': 0.8394633936788146, 'colsample_bytree': 0.6624074561769746, 'gamma': 0.7799726016810132, 'reg_alpha': 2.9152036385288193e-08, 'reg_lambda': 3.9676050770529883, 'num_boost_round': 2100}. Best is trial 0 with value: 0.25438285482034523.
# [I 2025-10-08 17:04:25,028] Trial 1 finished with value: 0.25940937156558697 and parameters: {'learning_rate': 0.05675206026988748, 'max_depth': 3, 'min_child_weight': 12, 'subsample': 0.9329770563201687, 'colsample_bytree': 0.6849356442713105, 'gamma': 0.9091248360355031, 'reg_alpha': 2.9324868872723725e-07, 'reg_lambda': 0.08179499475211674, 'num_boost_round': 2000}. Best is trial 0 with value: 0.25438285482034523.
# [I 2025-10-08 17:04:34,971] Trial 2 finished with value: 0.25944024927980674 and parameters: {'learning_rate': 0.01174843954800703, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0
. Best is trial 13 with value: 0.24633187366087864.
# [I 2025-10-08 17:15:08,111] Trial 52 finished with value: 0.25198014023016396 and parameters: {'learning_rate': 0.006950119694286558, 'max_depth': 7, 'min_child_weight': 12, 'subsample': 0.8055542581018694, 'colsample_bytree': 0.7119300261497985, 'gamma': 0.42270353758083673, 'reg_alpha': 0.5619207948163807, 'reg_lambda': 0.106199480092025, 'num_boost_round': 2300}. Best is trial 13 with value: 0.24633187366087864.
# [I 2025-10-08 17:15:29,052] Trial 53 finished with value: 0.24788603777966342 and parameters: {'learning_rate': 0.003608434516653512, 'max_depth': 8, 'min_child_weight': 4, 'subsample': 0.861544128296934, 'colsample_bytree': 0.7260731062979925, 'gamma': 0.13590254701274382, 'reg_alpha': 0.8395183938813972, 'reg_lambda': 0.4986613696217252, 'num_boost_round': 2500}. Best is trial 13 with value: 0.24633187366087864.
# [I 2025-10-08 17:15:45,977] Trial 54 finished with value: 0.251699799779353 and parameters: {'learning_rate': 0.0026233405572283507, 'max_depth': 7, 'min_child_weight': 7, 'subsample': 0.7914817491722687, 'colsample_bytree': 0.7885771489834178, 'gamma': 0.5522401880944847, 'reg_alpha': 0.12242029854076118, 'reg_lambda': 0.07443367845469931, 'num_boost_round': 2100}. Best is trial 13 with value: 0.24633187366087864.
# [I 2025-10-08 17:16:07,105] Trial 55 finished with value: 0.25568095902306964 and parameters: {'learning_rate': 0.0014633377065218023, 'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.8261188264182422, 'colsample_bytree': 0.8497329677816043, 'gamma': 0.002732591414200826, 'reg_alpha': 0.23544794151631357, 'reg_lambda': 0.1940970000145478, 'num_boost_round': 2000}. Best is trial 13 with value: 0.24633187366087864.
# [I 2025-10-08 17:16:20,129] Trial 56 finished with value: 0.24858926156131447 and parameters: {'learning_rate': 0.02048407186579465, 'max_depth': 6, 'min_child_weight': 6, 'subsample': 0.6679157043346209, 'colsample_bytree': 0.7580701521126023, 'gamma': 0.26555238620030885, 'reg_alpha': 0.002084416137311115, 'reg_lambda': 0.28947998117248175, 'num_boost_round': 2400}. Best is trial 13 with value: 0.24633187366087864.
# [I 2025-10-08 17:16:35,215] Trial 57 finished with value: 0.25055123995370393 and parameters: {'learning_rate': 0.004269655910222681, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.9164778060682173, 'colsample_bytree': 0.7373162878197416, 'gamma': 0.42793721877521695, 'reg_alpha': 0.02527051605339721, 'reg_lambda': 0.03070361188827996, 'num_boost_round': 1900}. Best is trial 13 with value: 0.24633187366087864.
# [I 2025-10-08 17:16:48,534] Trial 58 finished with value: 0.2529142659039231 and parameters: {'learning_rate': 0.005829587469185769, 'max_depth': 5, 'min_child_weight': 11, 'subsample': 0.7316093590660991, 'colsample_bytree': 0.9628238384125726, 'gamma': 0.6775104008989938, 'reg_alpha': 0.08042431889640497, 'reg_lambda': 1.6285393394421916, 'num_boost_round': 2700}. Best is trial 13 with value: 0.24633187366087864.
# [I 2025-10-08 17:16:58,878] Trial 59 finished with value: 0.24880087253674749 and parameters: {'learning_rate': 0.012183661349751533, 'max_depth': 9, 'min_child_weight': 8, 'subsample': 0.8757575938546078, 'colsample_bytree': 0.7004818256656935, 'gamma': 0.17417633759155748, 'reg_alpha': 0.011127186045592747, 'reg_lambda': 0.08341831181266869, 'num_boost_round': 2300}. Best is trial 13 with value: 0.24633187366087864.
#
# Mejores HP XGB (val RMSE_log ↓):
# {'n_estimators': 2291, 'learning_rate': 0.017150257367157886, 'max_depth': 7, 'min_child_weight': 6, 'subsample': 0.6014398847131033, 'colsample_bytree': 0.9880271934157469, 'gamma': 0.12774747405271736, 'reg_alpha': 0.032318743776449575, 'reg_lambda': 9.59454591610047, 'objective': 'reg:squarederror', 'random_state': 42}

# %%
# === Exportar hiperparámetros (ajusta la versión) ===
VERSION_TAG = "v1"  
os.makedirs("models_XGB", exist_ok=True)

save_path = os.path.join("models_XGB", f"best_params_XGB_{VERSION_TAG}.json")
with open(save_path, "w") as f:
    json.dump(best_params_sklearn, f, indent=2)

print(f"Hiperparámetros guardados en: {save_path}")
# Out:
# Hiperparámetros guardados en: models_XGB\best_params_XGB_v1.json

# %% [markdown]
# ### Hiperparametros para segundo modelo XGBoost --> Con coordenadas y sin VCR

# %%
#Configuración específica del modelo
df_coord =df_vcr_c.copy()
obj_cols = df_coord.select_dtypes(include=["object"]).columns
cols_to_drop = list(obj_cols)
cols_to_drop.append("id")
df_coord = df_coord.drop(columns=cols_to_drop)
df_coord.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25211 entries, 0 to 25214
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   monto                 25211 non-null  int64
#  1   superficie_t          25211 non-null  float64
#  2   dormitorios           25211 non-null  int64
#  3   dormitorios_faltante  25211 non-null  int64
#  4   banos                 25211 non-null  int64
#  5   banos_faltante        25211 non-null  int64
#  6   antiguedad            25211 non-null  int64
#  7   antiguedad_faltante   25211 non-null  int64
#  8   Or_N                  25211 non-null  int64
#  9   Or_S                  25211 non-null  int64
#  10  Or_E                  25211 non-null  int64
#  11  Or_O                  25211 non-null  int64
#  12  Or_Faltante           25211 non-null  int64
#  13  terraza               25211 non-null  float64
#  14  estacionamiento       25211 non-null  int64
#  15  bodegas               25211 non-null  int64
#  16  flag_Departamento     25211 non-null  int64
#  17  flag_Multinivel       25211 non-null  int64
#  18  flag_Semipiso         25211 non-null  int64
#  19  flag_Premium          25211 non-null  int64
#  20  flag_Monoambiente     25211 non-null  int64
#  21  flag_Loft             25211 non-null  int64
#  22  latitud               25211 non-null  float64
#  23  longitud              25211 non-null  float64
#  24  log_monto             25211 non-null  float64
# dtypes: float64(5), int64(20)
# memory usage: 5.0 MB

# %%
# Split
DF = df_coord
X = DF.drop(columns=["monto", "log_monto"]).copy()
y = DF["log_monto"].values

X_train_full, X_test, y_train_full, y_test = train_test_split(
    X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE
    )
X_train, X_val, y_train, y_val = train_test_split(
    X_train_full, y_train_full, test_size=VAL_SIZE, random_state=RANDOM_STATE
    )
print(f"Shapes -> train: {X_train.shape}, val: {X_val.shape}, test: {X_test.shape}")
# Out:
# Shapes -> train: (16134, 23), val: (4034, 23), test: (5043, 23)

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
dval   = xgb.DMatrix(X_val,   label=y_val)

# %%
def objective_xgb(trial):
    # Buscamos en NOMBRES estilo sklearn para que luego pasarlos directo al XGBRegressor
    params_skl = {
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.3, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 12),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "gamma": trial.suggest_float("gamma", 0.0, 5.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 1.0, log=True),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-2, 10.0, log=True),
    }
    num_boost_round = trial.suggest_int("num_boost_round", 800, 3000, step=100)

    # Mapear a nombres de xgb.train
    params_train = {
        "objective": "reg:squarederror",
        "eval_metric": "rmse",   # en LOG
        "device": "cuda",        # GPU obligatoria
        "seed": RANDOM_STATE,
        "eta": params_skl["learning_rate"],
        "max_depth": params_skl["max_depth"],
        "min_child_weight": params_skl["min_child_weight"],
        "subsample": params_skl["subsample"],
        "colsample_bytree": params_skl["colsample_bytree"],
        "gamma": params_skl["gamma"],
        "alpha": params_skl["reg_alpha"],
        "lambda": params_skl["reg_lambda"],
    }

    booster = xgb.train(
        params=params_train,
        dtrain=dtrain,
        num_boost_round=num_boost_round,
        evals=[(dval, "val")],
        early_stopping_rounds=EARLY_STOP_ROUNDS,
        verbose_eval=False,
    )

    y_val_pred_log = booster.predict(dval, iteration_range=(0, booster.best_iteration + 1))
    rmse_log_val = float(np.sqrt(np.mean((y_val - y_val_pred_log) ** 2)))
    # Guardar también n_estimators óptimo en los user_attrs del trial
    trial.set_user_attr("best_n_estimators", booster.best_iteration + 1)
    # Devolver params estilo sklearn (los leeremos después)
    for k, v in params_skl.items():
        trial.set_user_attr(k, v)
    return rmse_log_val

# %%
study = optuna.create_study(
    direction="minimize",
    sampler=TPESampler(seed=RANDOM_STATE),
    pruner=MedianPruner(n_startup_trials=5),
)
print("Optuna XGB: iniciando búsqueda...")
study.optimize(objective_xgb, n_trials=N_TRIALS_XGB, show_progress_bar=True)

t = study.best_trial
best_n_estimators = t.user_attrs["best_n_estimators"]
best_params_sklearn = {
    "n_estimators": best_n_estimators,
    "learning_rate": t.user_attrs["learning_rate"],
    "max_depth": t.user_attrs["max_depth"],
    "min_child_weight": t.user_attrs["min_child_weight"],
    "subsample": t.user_attrs["subsample"],
    "colsample_bytree": t.user_attrs["colsample_bytree"],
    "gamma": t.user_attrs["gamma"],
    "reg_alpha": t.user_attrs["reg_alpha"],
    "reg_lambda": t.user_attrs["reg_lambda"],
    "objective": "reg:squarederror",
    "random_state": RANDOM_STATE,
}
print("\nMejores HP XGB con coordenadas(val RMSE_log ↓):")
print({**best_params_sklearn})
# Out:
# [I 2025-10-08 17:36:55,243] A new study created in memory with name: no-name-752f5777-f9b2-4917-8cb7-807c2ea1734f
# Optuna XGB: iniciando búsqueda...
#   0%|          | 0/60 [00:00<?, ?it/s]
# [I 2025-10-08 17:37:10,941] Trial 0 finished with value: 0.18239654774617994 and parameters: {'learning_rate': 0.008468008575248327, 'max_depth': 10, 'min_child_weight': 9, 'subsample': 0.8394633936788146, 'colsample_bytree': 0.6624074561769746, 'gamma': 0.7799726016810132, 'reg_alpha': 2.9152036385288193e-08, 'reg_lambda': 3.9676050770529883, 'num_boost_round': 2100}. Best is trial 0 with value: 0.18239654774617994.
# [I 2025-10-08 17:37:15,635] Trial 1 finished with value: 0.19185196276566827 and parameters: {'learning_rate': 0.05675206026988748, 'max_depth': 3, 'min_child_weight': 12, 'subsample': 0.9329770563201687, 'colsample_bytree': 0.6849356442713105, 'gamma': 0.9091248360355031, 'reg_alpha': 2.9324868872723725e-07, 'reg_lambda': 0.08179499475211674, 'num_boost_round': 2000}. Best is trial 0 with value: 0.18239654774617994.
# [I 2025-10-08 17:37:22,384] Trial 2 finished with value: 0.1905545362853053 and parameters: {'learning_rate': 0.01174843954800703, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.6557975442608167, 'colsample_bytree': 0.7168578594140873, 'gamma': 1.8318092164684585, 'reg_alpha': 4.452048365748842e-05, 'reg_lambda': 2.267398652378039, 'num_boost_round': 1200}. Best is trial 0 with value: 0.18239654774617994.
# [I 2025-10-08 17:37:36,997] Trial 3 finished with value: 0.17793775373092016 and parameters: {'learning_rate': 0.018785426399210624, 'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.8430179407605753, 'colsample_bytree': 0.6682096494749166, 'gamma': 0.3252579649263976, 'reg_alpha': 0.39001768308022033, 'reg_lambda': 7.886714129990489, 'num_boost_round': 2600}. Best is trial 3 with value: 0.17793775373092016.
# [I 2025-10-08 17:37:45,405] Trial 4 finished with value: 0.19777892393989777 and parameters: {'learning_rate': 0.0056828375585122656, 'max_depth': 3, 'min_child_weight': 9, 'subsample': 0.7760609974958406, 'colsample_bytree': 0.6488152939379115, 'gamma': 2.475884550556351, 'reg_alpha': 1.8841183049085085e-08, 'reg_lambda': 5.345166110646819, 'num_boost_round': 1300}. Best is trial 3 with value: 0.17793775373092016.
# [I 2025-10-08 17:37:52,478] Trial 5 finished with value: 0.1993998833223918 and parameters: {'learning_rate': 0.043767126303409544, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0
 'max_depth': 6, 'min_child_weight': 7, 'subsample': 0.6258677398554287, 'colsample_bytree': 0.9000140525013864, 'gamma': 0.02216528188531427, 'reg_alpha': 4.475293711821796e-07, 'reg_lambda': 0.052106789670926024, 'objective': 'reg:squarederror', 'random_state': 42}

# %%
# === Exportar hiperparámetros (ajusta la versión) ===
VERSION_TAG = "v2"  
os.makedirs("models_XGB", exist_ok=True)

save_path = os.path.join("models_XGB", f"best_params_XGB_{VERSION_TAG}.json")
with open(save_path, "w") as f:
    json.dump(best_params_sklearn, f, indent=2)

print(f"Hiperparámetros guardados en: {save_path}")
# Out:
# Hiperparámetros guardados en: models_XGB\best_params_XGB_v2.json

# %% [markdown]
# ### Hiperparametros para tercer modelo XGBoost --> Con coordenadas y VCR

# %%
df_vcr_e = pd.read_csv('dataset_vcr_expanded.csv')
df_vcr_e = df_vcr_e[df_vcr_e['monto'] < 56000].copy()
df_vcr_e['log_monto']=np.log(df_vcr_e['monto'])
df_vcr_e['log_monto'].describe()
# Out:
# count    25211.000000
# mean         8.395828
# std          0.830310
# min          5.950643
# 25%          7.740664
# 50%          8.242756
# 75%          8.984694
# max         10.915088
# Name: log_monto, dtype: float64

# %%
df_vcr =df_vcr_e.copy()
obj_cols = df_vcr.select_dtypes(include=["object"]).columns
cols_to_drop = list(obj_cols)
cols_to_drop.append("id")
df_vcr = df_vcr.drop(columns=cols_to_drop)
df_vcr.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25211 entries, 0 to 25214
# Data columns (total 181 columns):
#  #    Column                        Dtype
# ---   ------                        -----
#  0    monto                         int64
#  1    superficie_t                  float64
#  2    dormitorios                   int64
#  3    dormitorios_faltante          int64
#  4    banos                         int64
#  5    banos_faltante                int64
#  6    antiguedad                    int64
#  7    antiguedad_faltante           int64
#  8    Or_N                          int64
#  9    Or_S                          int64
#  10   Or_E                          int64
#  11   Or_O                          int64
#  12   Or_Faltante                   int64
#  13   terraza                       float64
#  14   estacionamiento               int64
#  15   bodegas                       int64
#  16   flag_Departamento             int64
#  17   flag_Multinivel               int64
#  18   flag_Semipiso                 int64
#  19   flag_Premium                  int64
#  20   flag_Monoambiente             int64
#  21   flag_Loft                     int64
#  22   latitud                       float64
#  23   longitud                      float64
#  24   sport_and_leisure_dim00       float64
#  25   sport_and_leisure_dim01       float64
#  26   sport_and_leisure_dim02       float64
#  27   sport_and_leisure_dim03       float64
#  28   sport_and_leisure_dim04       float64
#  29   sport_and_leisure_dim05       float64
#  30   sport_and_leisure_dim06       float64
#  31   sport_and_leisure_dim07       float64
#  32   sport_and_leisure_dim08       float64
#  33   sport_and_leisure_dim09       float64
#  34   sport_and_leisure_dim10       float64
#  35   sport_and_leisure_dim11       float64
#  36   medical_dim00                 float64
#  37   medical_dim01                 float64
#  38   medical_dim02                 float64
#  39   medical_dim03                 float64
#  40   medical_dim04                 float64
#  41   medical_dim05                 float64
#  42   medical_dim06                 float64
#  43   medical_dim07                 float64
#  44   medical_dim08                 float64
#  45   medical_dim09                 float64
#  46   medical_dim10                 float64
#  47   medical_dim11                 float64
#  48   education_prim_dim00          float64
#  49   education_prim_dim01          float64
#  50   education_prim_dim02          float64
#  51   education_prim_dim03          float64
#  52   education_prim_dim04          float64
#  53   education_prim_dim05          float64
#  54   education_prim_dim06          float64
#  55   education_prim_dim07          float64
#  56   education_prim_dim08          float64
#  57   education_prim_dim09          float64
#  58   education_prim_dim10          float64
#  59   education_prim_dim11          float64
#  60   veterinary_dim00              float64
#  61   veterinary_dim01              float64
#  62   veterinary_dim02              float64
#  63   veterinary_dim03              float64
#  64   veterinary_dim04              float64
#  65   veterinary_dim05              float64
#  66   veterinary_dim06              float64
#  67   veterinary_dim07              float64
#  68   veterinary_dim08              float64
#  69   veterinary_dim09              float64
#  70   veterinary_dim10              float64
#  71   veterinary_dim11              float64
#  72   food_and_drink_stores_dim00   float64
#  73   food_and_drink_stores_dim01   float64
#  74   food_and_drink_stores_dim02   float64
#  75   food_and_drink_stores_dim03   float64
#  76   food_and_drink_stores_dim04   float64
#  77   food_and_drink_stores_dim05   float64
#  78   food_and_drink_stores_dim06   float64
#  79   food_and_drink_stores_dim07   float64
#  80   food_and_drink_stores_dim08   float64
#  81   food_and_drink_stores_dim09   float64
#  82   food_and_drink_stores_dim10   float64
#  83   food_and_drink_stores_dim11   float64
#  84   arts_and_entertainment_dim00  float64
#  85   arts_and_entertainment_dim01  float64
#  86   arts_and_entertainment_dim02  float64
#  87   arts_and_entertainment_dim03  float64
#  88   arts_and_entertainment_dim04  float64
#  89   arts_and_entertainment_dim05  float64
#  90   arts_and_entertainment_dim06  float64
#  91   arts_and_entertainment_dim07  float64
#  92   arts_and_entertainment_dim08  float64
#  93   arts_and_entertainment_dim09  float64
#  94   arts_and_entertainment_dim10  float64
#  95   arts_and_entertainment_dim11  float64
#  96   food_and_drink_dim00          float64
#  97   food_and_drink_dim01          float64
#  98   food_and_drink_dim02          float64
#  99   food_and_drink_dim03          float64
#  100  food_and_drink_dim04          float64
#  101  food_and_drink_dim05          float64
#  102  food_and_drink_dim06          float64
#  103  food_and_drink_dim07          float64
#  104  food_and_drink_dim08          float64
#  105  food_and_drink_dim09          float64
#  106  food_and_drink_dim10          float64
#  107  food_and_drink_dim11          float64
#  108  park_like_dim00               float64
#  109  park_like_dim01               float64
#  110  park_like_dim02               float64
#  111  park_like_dim03               float64
#  112  park_like_dim04               float64
#  113  park_like_dim05               float64
#  114  park_like_dim06               float64
#  115  park_like_dim07               float64
#  116  park_like_dim08               float64
#  117  park_like_dim09               float64
#  118  park_like_dim10               float64
#  119  park_like_dim11               float64
#  120  security_dim00                float64
#  121  security_dim01                float64
#  122  security_dim02                float64
#  123  security_dim03                float64
#  124  security_dim04                float64
#  125  security_dim05                float64
#  126  security_dim06                float64
#  127  security_dim07                float64
#  128  security_dim08                float64
#  129  security_dim09                float64
#  130  security_dim10                float64
#  131  security_dim11                float64
#  132  religion_dim00                float64
#  133  religion_dim01                float64
#  134  religion_dim02                float64
#  135  religion_dim03                float64
#  136  religion_dim04                float64
#  137  religion_dim05                float64
#  138  religion_dim06                float64
#  139  religion_dim07                float64
#  140  religion_dim08                float64
#  141  religion_dim09                float64
#  142  religion_dim10                float64
#  143  religion_dim11                float64
#  144  education_sup_dim00           float64
#  145  education_sup_dim01           float64
#  146  education_sup_dim02           float64
#  147  education_sup_dim03           float64
#  148  education_sup_dim04           float64
#  149  education_sup_dim05           float64
#  150  education_sup_dim06           float64
#  151  education_sup_dim07           float64
#  152  education_sup_dim08           float64
#  153  education_sup_dim09           float64
#  154  education_sup_dim10           float64
#  155  education_sup_dim11           float64
#  156  metro_dim00                   float64
#  157  metro_dim01                   float64
#  158  metro_dim02                   float64
#  159  metro_dim03                   float64
#  160  metro_dim04                   float64
#  161  metro_dim05                   float64
#  162  metro_dim06                   float64
#  163  metro_dim07                   float64
#  164  metro_dim08                   float64
#  165  metro_dim09                   float64
#  166  metro_dim10                   float64
#  167  metro_dim11                   float64
#  168  bus_dim00                     float64
#  169  bus_dim01                     float64
#  170  bus_dim02                     float64
#  171  bus_dim03                     float64
#  172  bus_dim04                     float64
#  173  bus_dim05                     float64
#  174  bus_dim06                     float64
#  175  bus_dim07                     float64
#  176  bus_dim08                     float64
#  177  bus_dim09                     float64
#  178  bus_dim10                     float64
#  179  bus_dim11                     float64
#  180  log_monto                     float64
# dtypes: float64(161), int64(20)
# memory usage: 35.0 MB

# %%
# %% Configuración 
# Dimensiones (1..12) 
DIMS_MAP = {
    1: "count_pois",
    2: "mean_distance",
    3: "min_distance",
    4: "max_distance",
    5: "median_distance",
    6: "std_distance",
    7: "mean_inverse_distance",
    8: "max_inverse_distance",
    9: "sum_inverse_distance",
    10: "ratio_within_near_radius",
    11: "ratio_within_mid_radius",
    12: "ratio_within_far_radius",
}

# Rol por dimensión (para decidir la imputación semántica)
DIM_ROLE = {
    1: "count",                # -> 0
    2: "distance",             # -> R3
    3: "distance",             # -> R3
    4: "distance",             # -> R3
    5: "distance",             # -> R3
    6: "std",                  # -> 0
    7: "inverse",              # -> 0
    8: "inverse",              # -> 0
    9: "inverse",              # -> 0
    10: "ratio",               # -> 0
    11: "ratio",               # -> 0
    12: "ratio",               # -> 0
}

# R3 por tipo de clase
R3_DEFAULT = 2400.0  # clases generales
R3_METRO = 1600.0
R3_BUS = 800.0

# %% Funciones
def _class_and_dim(col: str) -> Optional[Tuple[str, int]]:
    """Extrae (clase, índice de dimensión) de columnas tipo '<clase>_dimXX'."""
    m = re.match(r"^(?P<klass>.+)_dim(?P<idx>\d{1,2})$", col)
    if not m:
        return None
    return m.group("klass"), int(m.group("idx"))


def _r3_for_class(klass: str) -> float:
    k = klass.lower()
    if "metro" in k:
        return R3_METRO
    if "bus" in k:
        return R3_BUS
    return R3_DEFAULT


def impute_vcr_semantic(df: pd.DataFrame) -> pd.DataFrame:
    """Imputa VCR por semántica de ausencia: distancias=R3, inversas/ratios=0, count=0, std=0.
    Además agrega flags `has_<clase>` indicando presencia de POIs por clase.
    """
    out = df.copy()

    # Agrupar columnas por clase
    groups: Dict[str, Dict[int, str]] = {}
    vcr_cols = []
    for c in out.columns:
        parsed = _class_and_dim(c)
        if parsed is None:
            continue
        klass, idx = parsed
        groups.setdefault(klass, {})[idx] = c
        vcr_cols.append(c)

    if not groups:
        # Nada que imputar
        return out

    # Flags de presencia por clase (antes de imputar)
    for klass, dim_map in groups.items():
        cols = list(dim_map.values())
        has_series = out[cols].notna().any(axis=1).astype("int64")
        out[f"has_{klass}"] = has_series  # por qué: distingue ausencia real vs lejanía

    # Imputación por clase/dim
    n_total_nans = int(out[vcr_cols].isna().sum().sum())
    for klass, dim_map in groups.items():
        r3 = _r3_for_class(klass)
        for idx, col in dim_map.items():
            role = DIM_ROLE.get(idx)
            if role == "distance":
                fill_value = r3
            elif role in {"inverse", "ratio", "std", "count"}:
                fill_value = 0.0
            else:
                # Si hay una dimensión desconocida, ser conservador con 0.0
                fill_value = 0.0
            out[col] = out[col].fillna(fill_value)

    n_after_nans = int(out[vcr_cols].isna().sum().sum())
    print(f"Imputación VCR completada. NaNs antes: {n_total_nans:,d} -> después: {n_after_nans:,d}")

    return out


df_vcr_imp = impute_vcr_semantic(df_vcr)
df_vcr_imp.info()
# Out:
# Imputación VCR completada. NaNs antes: 246,228 -> después: 0
# <class 'pandas.core.frame.DataFrame'>
# Index: 25211 entries, 0 to 25214
# Columns: 194 entries, monto to has_bus
# dtypes: float64(161), int64(33)
# memory usage: 37.5 MB

# %%
# Split
DF = df_vcr_imp
X = DF.drop(columns=["monto", "log_monto"]).copy()
y = DF["log_monto"].values

X_train_full, X_test, y_train_full, y_test = train_test_split(
X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE
)
X_train, X_val, y_train, y_val = train_test_split(
X_train_full, y_train_full, test_size=VAL_SIZE, random_state=RANDOM_STATE
)
print(f"Shapes -> train: {X_train.shape}, val: {X_val.shape}, test: {X_test.shape}")
# Out:
# Shapes -> train: (16134, 192), val: (4034, 192), test: (5043, 192)

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
dval   = xgb.DMatrix(X_val,   label=y_val)

# %%
def objective_xgb(trial):
    # Buscamos en NOMBRES estilo sklearn para que luego pasarlos directo al XGBRegressor
    params_skl = {
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.3, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 12),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "gamma": trial.suggest_float("gamma", 0.0, 5.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 1.0, log=True),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-2, 10.0, log=True),
    }
    num_boost_round = trial.suggest_int("num_boost_round", 800, 3000, step=100)

    # Mapear a nombres de xgb.train
    params_train = {
        "objective": "reg:squarederror",
        "eval_metric": "rmse",   # en LOG
        "device": "cuda",        # GPU obligatoria
        "seed": RANDOM_STATE,
        "eta": params_skl["learning_rate"],
        "max_depth": params_skl["max_depth"],
        "min_child_weight": params_skl["min_child_weight"],
        "subsample": params_skl["subsample"],
        "colsample_bytree": params_skl["colsample_bytree"],
        "gamma": params_skl["gamma"],
        "alpha": params_skl["reg_alpha"],
        "lambda": params_skl["reg_lambda"],
    }

    booster = xgb.train(
        params=params_train,
        dtrain=dtrain,
        num_boost_round=num_boost_round,
        evals=[(dval, "val")],
        early_stopping_rounds=EARLY_STOP_ROUNDS,
        verbose_eval=False,
    )

    y_val_pred_log = booster.predict(dval, iteration_range=(0, booster.best_iteration + 1))
    rmse_log_val = float(np.sqrt(np.mean((y_val - y_val_pred_log) ** 2)))
    # Guardar también n_estimators óptimo en los user_attrs del trial
    trial.set_user_attr("best_n_estimators", booster.best_iteration + 1)
    # Devolver params estilo sklearn (los leeremos después)
    for k, v in params_skl.items():
        trial.set_user_attr(k, v)
    return rmse_log_val

# %%
study = optuna.create_study(
    direction="minimize",
    sampler=TPESampler(seed=RANDOM_STATE),
    pruner=MedianPruner(n_startup_trials=5),
)
print("Optuna XGB: iniciando búsqueda...")
study.optimize(objective_xgb, n_trials=N_TRIALS_XGB, show_progress_bar=True)

t = study.best_trial
best_n_estimators = t.user_attrs["best_n_estimators"]
best_params_sklearn = {
    "n_estimators": best_n_estimators,
    "learning_rate": t.user_attrs["learning_rate"],
    "max_depth": t.user_attrs["max_depth"],
    "min_child_weight": t.user_attrs["min_child_weight"],
    "subsample": t.user_attrs["subsample"],
    "colsample_bytree": t.user_attrs["colsample_bytree"],
    "gamma": t.user_attrs["gamma"],
    "reg_alpha": t.user_attrs["reg_alpha"],
    "reg_lambda": t.user_attrs["reg_lambda"],
    "objective": "reg:squarederror",
    "random_state": RANDOM_STATE,
}
print("\nMejores HP XGB completo (val RMSE_log ↓):")
print({**best_params_sklearn})
# Out:
# [I 2025-10-08 17:51:35,987] A new study created in memory with name: no-name-8f947f13-5979-456a-9ff4-35be181bea9a
# Optuna XGB: iniciando búsqueda...
#   0%|          | 0/60 [00:00<?, ?it/s]
# [I 2025-10-08 17:51:56,009] Trial 0 finished with value: 0.17462495238637127 and parameters: {'learning_rate': 0.008468008575248327, 'max_depth': 10, 'min_child_weight': 9, 'subsample': 0.8394633936788146, 'colsample_bytree': 0.6624074561769746, 'gamma': 0.7799726016810132, 'reg_alpha': 2.9152036385288193e-08, 'reg_lambda': 3.9676050770529883, 'num_boost_round': 2100}. Best is trial 0 with value: 0.17462495238637127.
# [I 2025-10-08 17:52:00,442] Trial 1 finished with value: 0.1850335463882574 and parameters: {'learning_rate': 0.05675206026988748, 'max_depth': 3, 'min_child_weight': 12, 'subsample': 0.9329770563201687, 'colsample_bytree': 0.6849356442713105, 'gamma': 0.9091248360355031, 'reg_alpha': 2.9324868872723725e-07, 'reg_lambda': 0.08179499475211674, 'num_boost_round': 2000}. Best is trial 0 with value: 0.17462495238637127.
# [I 2025-10-08 17:52:08,873] Trial 2 finished with value: 0.18525487304533986 and parameters: {'learning_rate': 0.01174843954800703, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.6557975442608167, 'colsample_bytree': 0.7168578594140873, 'gamma': 1.8318092164684585, 'reg_alpha': 4.452048365748842e-05, 'reg_lambda': 2.267398652378039, 'num_boost_round': 1200}. Best is trial 0 with value: 0.17462495238637127.
# [I 2025-10-08 17:52:28,959] Trial 3 finished with value: 0.1696029004489747 and parameters: {'learning_rate': 0.018785426399210624, 'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.8430179407605753, 'colsample_bytree': 0.6682096494749166, 'gamma': 0.3252579649263976, 'reg_alpha': 0.39001768308022033, 'reg_lambda': 7.886714129990489, 'num_boost_round': 2600}. Best is trial 3 with value: 0.1696029004489747.
# [I 2025-10-08 17:52:39,272] Trial 4 finished with value: 0.1914896918630934 and parameters: {'learning_rate': 0.0056828375585122656, 'max_depth': 3, 'min_child_weight': 9, 'subsample': 0.7760609974958406, 'colsample_bytree': 0.6488152939379115, 'gamma': 2.475884550556351, 'reg_alpha': 1.8841183049085085e-08, 'reg_lambda': 5.345166110646819, 'num_boost_round': 1300}. Best is trial 3 with value: 0.1696029004489747.
# [I 2025-10-08 17:52:46,138] Trial 5 finished with value: 0.19361224477392222 and parameters: {'learning_rate': 0.043767126303409544, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0
. Best is trial 32 with value: 0.16265028649442811.
# [I 2025-10-08 18:06:42,620] Trial 53 finished with value: 0.17160136824903124 and parameters: {'learning_rate': 0.006945738155109998, 'max_depth': 7, 'min_child_weight': 8, 'subsample': 0.9448648812205124, 'colsample_bytree': 0.6726354750498346, 'gamma': 0.5133490259457247, 'reg_alpha': 9.093421957465077e-07, 'reg_lambda': 2.8147592716664764, 'num_boost_round': 2500}. Best is trial 32 with value: 0.16265028649442811.
# [I 2025-10-08 18:07:09,910] Trial 54 finished with value: 0.16568828143369288 and parameters: {'learning_rate': 0.003366264924385628, 'max_depth': 7, 'min_child_weight': 10, 'subsample': 0.8506950034785576, 'colsample_bytree': 0.6273203111238806, 'gamma': 0.037745047453622546, 'reg_alpha': 2.6066485856904182e-08, 'reg_lambda': 5.500805005773677, 'num_boost_round': 2100}. Best is trial 32 with value: 0.16265028649442811.
# [I 2025-10-08 18:07:46,488] Trial 55 finished with value: 0.16530457988750036 and parameters: {'learning_rate': 0.002371035978156283, 'max_depth': 8, 'min_child_weight': 11, 'subsample': 0.8217642925732547, 'colsample_bytree': 0.6116066490204994, 'gamma': 0.002732591414200826, 'reg_alpha': 5.458983353138664e-06, 'reg_lambda': 5.81348833354805, 'num_boost_round': 2400}. Best is trial 32 with value: 0.16265028649442811.
# [I 2025-10-08 18:08:19,859] Trial 56 finished with value: 0.17105032287789618 and parameters: {'learning_rate': 0.0023548662701687833, 'max_depth': 9, 'min_child_weight': 11, 'subsample': 0.8269743277712119, 'colsample_bytree': 0.6172195630923425, 'gamma': 0.38282856885703037, 'reg_alpha': 5.116714957523577e-06, 'reg_lambda': 6.042872135045481, 'num_boost_round': 2400}. Best is trial 32 with value: 0.16265028649442811.
# [I 2025-10-08 18:09:07,631] Trial 57 finished with value: 0.17646577546935086 and parameters: {'learning_rate': 0.0012304772946036173, 'max_depth': 8, 'min_child_weight': 12, 'subsample': 0.7762691398224756, 'colsample_bytree': 0.6019475437794737, 'gamma': 0.07058756822692036, 'reg_alpha': 3.090622570635108e-06, 'reg_lambda': 8.73639040489631, 'num_boost_round': 2800}. Best is trial 32 with value: 0.16265028649442811.
# [I 2025-10-08 18:09:33,162] Trial 58 finished with value: 0.17311448547841335 and parameters: {'learning_rate': 0.003785092045535369, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.7930752807697424, 'colsample_bytree': 0.6252504173843819, 'gamma': 0.574718245021337, 'reg_alpha': 2.057297733329421e-05, 'reg_lambda': 4.886806587505298, 'num_boost_round': 2300}. Best is trial 32 with value: 0.16265028649442811.
# [I 2025-10-08 18:09:52,323] Trial 59 finished with value: 0.1747446976300646 and parameters: {'learning_rate': 0.02490446442366752, 'max_depth': 8, 'min_child_weight': 11, 'subsample': 0.8531810219747163, 'colsample_bytree': 0.6500178056403755, 'gamma': 0.8114169172551048, 'reg_alpha': 0.014018691094613931, 'reg_lambda': 0.06938071262591126, 'num_boost_round': 2700}. Best is trial 32 with value: 0.16265028649442811.
#
# Mejores HP XGB completo (val RMSE_log ↓):
# {'n_estimators': 1428, 'learning_rate': 0.010191584888554761, 'max_depth': 7, 'min_child_weight': 7, 'subsample': 0.8555660832547627, 'colsample_bytree': 0.6849734591903663, 'gamma': 0.023675974765307806, 'reg_alpha': 0.16031436057521933, 'reg_lambda': 1.1452181939095467, 'objective': 'reg:squarederror', 'random_state': 42}

# %%
# === Exportar hiperparámetros ===
VERSION_TAG = "v3"  
os.makedirs("models_XGB", exist_ok=True)

save_path = os.path.join("models_XGB", f"best_params_XGB_{VERSION_TAG}.json")
with open(save_path, "w") as f:
    json.dump(best_params_sklearn, f, indent=2)

print(f"Hiperparámetros guardados en: {save_path}")
# Out:
# Hiperparámetros guardados en: models_XGB\best_params_XGB_v3.json
